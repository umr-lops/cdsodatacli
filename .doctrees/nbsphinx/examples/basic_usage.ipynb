# %%
"""
started 6 nov 2023
A Grouazel, based on JR Miadana dev
"""
# Out:
# '\nstarted 6 nov 2023\nA Grouazel, based on JR Miadana dev\n'

# %%
import datetime
import shapely
import geopandas as gpd
import cdsodatacli

# %% [markdown]
# # define a GeoDataFrame

# %%
gdf = gpd.GeoDataFrame({
        "start_datetime" : [ datetime.datetime(2022,10,2,0) ,  datetime.datetime(2022,10,13,0) ],
        "end_datetime"   : [ datetime.datetime(2022,10,2,21),  datetime.datetime(2022,10,13,18) ],
        "geometry"   : [ shapely.wkt.loads("POINT (-7.5 53)"),  shapely.wkt.loads("POLYGON ((-12 35, -5 35, -5 45, -12 45, -12 35))")],
        "collection"  : [ "SENTINEL-1", "SENTINEL-2"],
        "name"        : [ None, None],
        "sensormode"  : [ None, None],
        "producttype" : [ None, None],
        "Attributes"  : [ None, None],
        "id_query"    : ['S1example','S2polygon'],
    })

collected_data_norm = cdsodatacli.query.fetch_data(gdf, min_sea_percent=20)
# Out:
# Downloading file 'ne_110m_land.zip' from 'https://naciscdn.org/naturalearth/110m/physical/ne_110m_land.zip' to '/home/runner/.cache/geodatasets'.
# /home/runner/work/cdsodatacli/cdsodatacli/cdsodatacli/query.py:914: UserWarning: Geometry is in a geographic CRS. Results from 'area' are likely incorrect. Use 'GeoSeries.to_crs()' to re-project geometries to a projected CRS before this operation.
#
#   collected_data.geometry.area
# /home/runner/work/cdsodatacli/cdsodatacli/cdsodatacli/query.py:915: UserWarning: Geometry is in a geographic CRS. Results from 'area' are likely incorrect. Use 'GeoSeries.to_crs()' to re-project geometries to a projected CRS before this operation.
#
#   - collected_data.geometry.intersection(earth.unary_union).area
# /home/runner/work/cdsodatacli/cdsodatacli/cdsodatacli/query.py:917: UserWarning: Geometry is in a geographic CRS. Results from 'area' are likely incorrect. Use 'GeoSeries.to_crs()' to re-project geometries to a projected CRS before this operation.
#
#   / collected_data.geometry.area

# %%
collected_data_norm.head()
# Out:
#      @odata.mediaContentType                                    Id  \
# 82  application/octet-stream  036c7c34-dcd5-4e50-b1c1-c48a229dbc37
# 86  application/octet-stream  f5e9137d-2bc6-4c1b-b6d5-1a0e50444cc1
# 84  application/octet-stream  ce9592ff-6e87-46d7-82d9-ae4ac8a53b7f
# 70  application/octet-stream  51c6817b-bd79-4f51-8e52-494ed4133414
# 89  application/octet-stream  aabb05a6-f728-4ee8-baad-9865d7faa020
#
#                                                  Name  \
# 82  S2A_MSIL2A_20221013T111011_N0510_R137_T29SQU_2...
# 86  S2A_MSIL2A_20221013T111011_N0510_R137_T30TUP_2...
# 84  S2A_MSIL2A_20221013T111011_N0510_R137_T30TUQ_2...
# 70  S2A_MSIL2A_20221013T111011_N0510_R137_T29TQK_2...
# 89  S2A_MSIL2A_20221013T111011_N0510_R137_T29SQA_2...
#
#                  ContentType  ContentLength                   OriginDate  \
# 82  application/octet-stream     1073335509  2025-03-21T20:48:29.526000Z
# 86  application/octet-stream      853795556  2025-03-21T20:48:30.542000Z
# 84  application/octet-stream      805327544  2025-03-21T20:48:30.573000Z
# 70  application/octet-stream      327227168  2025-03-21T20:48:29.821000Z
# 89  application/octet-stream     1044396139  2025-03-21T20:48:29.314000Z
#
#                 PublicationDate             ModificationDate  Online  \
# 82  2025-04-05T21:12:29.865181Z  2025-04-05T21:12:29.865181Z    True
# 86  2025-04-05T21:12:20.047719Z  2025-04-05T21:12:20.047719Z    True
# 84  2025-04-05T21:11:22.035914Z  2025-04-05T21:11:22.035914Z    True
# 70  2025-04-05T21:09:19.827827Z  2025-04-05T21:09:19.827827Z    True
# 89  2025-04-05T21:09:19.354210Z  2025-04-05T21:09:19.354210Z    True
#
#                    EvictionDate  \
# 82  9999-12-31T23:59:59.999999Z
# 86  9999-12-31T23:59:59.999999Z
# 84  9999-12-31T23:59:59.999999Z
# 70  9999-12-31T23:59:59.999999Z
# 89  9999-12-31T23:59:59.999999Z
#
#                                                S3Path  \
# 82  /eodata/Sentinel-2/MSI/L2A_N0500/2022/10/13/S2...
# 86  /eodata/Sentinel-2/MSI/L2A_N0500/2022/10/13/S2...
# 84  /eodata/Sentinel-2/MSI/L2A_N0500/2022/10/13/S2...
# 70  /eodata/Sentinel-2/MSI/L2A_N0500/2022/10/13/S2...
# 89  /eodata/Sentinel-2/MSI/L2A_N0500/2022/10/13/S2...
#
#                                              Checksum  \
# 82  [{'Value': 'e00637d4e1bf8b1b0ece0c3c80142e19',...
# 86  [{'Value': '5c470b724593095c62dfb8b37a0abd08',...
# 84  [{'Value': '7d2ac3cd44f2a6adb1665e9fe609883c',...
# 70  [{'Value': '0366fec8a1410e70f362d7e8603fd712',...
# 89  [{'Value': 'dc68bc5266be6608f87c2ce2b0d44849',...
#
#                                           ContentDate  \
# 82  {'Start': '2022-10-13T11:10:11.024000Z', 'End'...
# 86  {'Start': '2022-10-13T11:10:11.024000Z', 'End'...
# 84  {'Start': '2022-10-13T11:10:11.024000Z', 'End'...
# 70  {'Start': '2022-10-13T11:10:11.024000Z', 'End'...
# 89  {'Start': '2022-10-13T11:10:11.024000Z', 'End'...
#
#                                             Footprint  \
# 82  geography'SRID=4326;POLYGON ((-6.8028975671597...
# 86  geography'SRID=4326;POLYGON ((-5.5040714070962...
# 84  geography'SRID=4326;POLYGON ((-5.5312609072621...
# 70  geography'SRID=4326;POLYGON ((-5.7777125094904...
# 89  geography'SRID=4326;POLYGON ((-6.7520694569753...
#
#                                          GeoFootprint  \
# 82  {'type': 'Polygon', 'coordinates': [[[-6.80289...
# 86  {'type': 'Polygon', 'coordinates': [[[-5.50407...
# 84  {'type': 'Polygon', 'coordinates': [[[-5.53126...
# 70  {'type': 'Polygon', 'coordinates': [[[-5.77771...
# 89  {'type': 'Polygon', 'coordinates': [[[-6.75206...
#
#                                            Attributes id_original_query  \
# 82  [{'@odata.type': '#OData.CSC.StringAttribute',...         S2polygon
# 86  [{'@odata.type': '#OData.CSC.StringAttribute',...         S2polygon
# 84  [{'@odata.type': '#OData.CSC.StringAttribute',...         S2polygon
# 70  [{'@odata.type': '#OData.CSC.StringAttribute',...         S2polygon
# 89  [{'@odata.type': '#OData.CSC.StringAttribute',...         S2polygon
#
#                                              geometry  sea_percent
# 82  POLYGON ((-6.8029 35.22313, -6.82894 34.2337, ...    24.846154
# 86  POLYGON ((-5.50407 44.22596, -5.46323 43.23826...    76.801415
# 84  POLYGON ((-5.53126 44.85138, -5.50035 44.138, ...   100.000000
# 70  POLYGON ((-5.77771 44.11785, -5.13001 44.09977...   100.000000
# 89  POLYGON ((-6.75207 37.02528, -6.78053 36.03618...    39.204398
