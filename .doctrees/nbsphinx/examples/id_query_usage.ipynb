# %% [markdown]
# # How to use 'id_query' ?

# %% [markdown]
# the 'id_query' is used in the Geo Pandas DataFrame as a key to distinguish different requests passed through the same GeoDataFrame.
#
# Exact same query given twice with distinct 'id_query' will result in excact same results but stored twice in the output DataFrame.
#
# The 'id_query' is also stored in the output DataFrame as 'id_original_query'.

# %%
import geopandas as gpd
import numpy as np
import cdsodatacli.query as qr
def example():
    """
    define a query with 2 identical sets of parameters except 'id_query'
    """
    gdf_multi_id = gpd.GeoDataFrame(
        {
            "start_datetime": [
                np.datetime64("2022-05-03 00:00:00"),
                np.datetime64("2022-05-03 00:00:00"),
            ],
            "end_datetime": [
                np.datetime64("2022-05-03 00:02:00"),
                np.datetime64("2022-05-03 00:02:00"),
            ],
            "geometry": [None, None],
            "collection": ["SENTINEL-2", "SENTINEL-2"],
            "name": [None, None],
            "sensormode": [None, None],
            "producttype": [None, None],
            "Attributes": [None, None],
            "id_query": ["test1", "test2"],
        }
    )
    result = qr.fetch_data(gdf=gdf_multi_id, top=1000)
    # check that a product is present twice with different id_original_query
    counts = result["id_original_query"].value_counts()
    return result,counts

# %%
result,counts = example()
assert all(counts[counts > 1].index.isin(["test1", "test2"]))
result
# Out:
#       @odata.mediaContentType                                    Id  \
# 0    application/octet-stream  7b561bb5-bb5c-476a-ac51-d361cace788d
# 1    application/octet-stream  f05036fd-66ee-42bb-a12f-92b319f4c7fb
# 2    application/octet-stream  b2f271b3-0217-4dcd-93b3-29ceb81b78f1
# 3    application/octet-stream  9501c4d2-4315-4033-8fc0-6ffdb6ed0a8a
# 4    application/octet-stream  6b7817c3-a120-4c1b-9d00-672249307e85
# ..                        ...                                   ...
# 151  application/octet-stream  cc29e73b-56b3-4a48-bce6-268785ee7d34
# 152  application/octet-stream  7832c103-0838-49a2-bb80-6c932cab908d
# 153  application/octet-stream  ba0acd60-ae9a-4282-8a5f-a313fe8cfdcf
# 154  application/octet-stream  0714ebc9-4b3e-416d-a6c3-bb51ce28e5c4
# 155  application/octet-stream  877b73c7-da3a-4f64-b46b-a8c8d8050fb2
#
#                                                   Name  \
# 0    S2B_MSIL2A_20220503T000139_N0510_R016_T11XML_2...
# 1    S2B_MSIL2A_20220503T000139_N0510_R016_T08XNR_2...
# 2    S2B_MSIL1C_20220503T000139_N0510_R016_T07XEL_2...
# 3    S2B_MSIL2A_20220503T000139_N0510_R016_T10XER_2...
# 4    S2B_MSIL2A_20220503T000139_N0510_R016_T07XEL_2...
# ..                                                 ...
# 151  S2B_MSIL1C_20220503T000139_N0510_R016_T06XWR_2...
# 152  S2B_MSIL1C_20220503T000139_N0510_R016_T11XMJ_2...
# 153  S2B_MSIL1C_20220503T000139_N0510_R016_T10XEP_2...
# 154  S2B_MSIL1C_20220503T000139_N0510_R016_T06XWS_2...
# 155  S2B_MSIL1C_20220503T000139_N0510_R016_T07XDK_2...
#
#                   ContentType  ContentLength                   OriginDate  \
# 0    application/octet-stream      905950656  2024-10-22T03:57:01.163000Z
# 1    application/octet-stream      906648145  2024-10-22T03:56:59.617000Z
# 2    application/octet-stream      739061869  2024-10-22T03:56:56.046000Z
# 3    application/octet-stream      906168896  2024-10-22T03:57:00.756000Z
# 4    application/octet-stream      899169465  2024-10-22T03:56:59.076000Z
# ..                        ...            ...                          ...
# 151  application/octet-stream      201206381  2024-10-22T03:56:55.563000Z
# 152  application/octet-stream       65098736  2024-10-22T03:56:57.926000Z
# 153  application/octet-stream       76120489  2024-10-22T03:56:57.524000Z
# 154  application/octet-stream       16311928  2024-10-22T03:56:55.646000Z
# 155  application/octet-stream       17579643  2024-10-22T03:56:55.731000Z
#
#                  PublicationDate             ModificationDate  Online  \
# 0    2024-11-30T10:52:42.448541Z  2024-11-30T10:52:58.857924Z    True
# 1    2024-11-30T10:52:13.209895Z  2024-11-30T10:52:24.656867Z    True
# 2    2024-11-30T10:51:43.843079Z  2024-11-30T10:51:54.844138Z    True
# 3    2024-11-30T10:51:41.950143Z  2024-11-30T10:51:53.955437Z    True
# 4    2024-11-30T10:51:11.639296Z  2024-11-30T10:51:22.361116Z    True
# ..                           ...                          ...     ...
# 151  2024-11-30T10:45:08.042394Z  2024-11-30T10:45:13.163135Z    True
# 152  2024-11-30T10:45:07.858114Z  2024-11-30T10:45:11.861222Z    True
# 153  2024-11-30T10:45:07.824853Z  2024-11-30T10:45:11.755815Z    True
# 154  2024-11-30T10:45:07.313818Z  2024-11-30T10:45:11.288750Z    True
# 155  2024-11-30T10:45:07.375601Z  2024-11-30T10:45:10.435212Z    True
#
#                     EvictionDate  \
# 0    9999-12-31T23:59:59.999999Z
# 1    9999-12-31T23:59:59.999999Z
# 2    9999-12-31T23:59:59.999999Z
# 3    9999-12-31T23:59:59.999999Z
# 4    9999-12-31T23:59:59.999999Z
# ..                           ...
# 151  9999-12-31T23:59:59.999999Z
# 152  9999-12-31T23:59:59.999999Z
# 153  9999-12-31T23:59:59.999999Z
# 154  9999-12-31T23:59:59.999999Z
# 155  9999-12-31T23:59:59.999999Z
#
#                                                 S3Path  \
# 0    /eodata/Sentinel-2/MSI/L2A_N0500/2022/05/03/S2...
# 1    /eodata/Sentinel-2/MSI/L2A_N0500/2022/05/03/S2...
# 2    /eodata/Sentinel-2/MSI/L1C_N0500/2022/05/03/S2...
# 3    /eodata/Sentinel-2/MSI/L2A_N0500/2022/05/03/S2...
# 4    /eodata/Sentinel-2/MSI/L2A_N0500/2022/05/03/S2...
# ..                                                 ...
# 151  /eodata/Sentinel-2/MSI/L1C_N0500/2022/05/03/S2...
# 152  /eodata/Sentinel-2/MSI/L1C_N0500/2022/05/03/S2...
# 153  /eodata/Sentinel-2/MSI/L1C_N0500/2022/05/03/S2...
# 154  /eodata/Sentinel-2/MSI/L1C_N0500/2022/05/03/S2...
# 155  /eodata/Sentinel-2/MSI/L1C_N0500/2022/05/03/S2...
#
#                                               Checksum  \
# 0    [{'Value': '8dc89dabd44eb3869de612042a6a427d',...
# 1    [{'Value': '8e855e16387253f7aca2fcf38b0d85fb',...
# 2    [{'Value': 'f514d8376518117f2e345263982d4ec1',...
# 3    [{'Value': '6ee6c35e7a4fb8ad3913279ad053d32a',...
# 4    [{'Value': 'a54d86f0a52c6588bcc1fd581a8d2b42',...
# ..                                                 ...
# 151  [{'Value': '8faec36c74e72f561fb34c5dd91d7219',...
# 152  [{'Value': 'beb4e8fd14b8bb124ef0109753c9c85d',...
# 153  [{'Value': 'bf216267943adf61f51b6f858ab6192e',...
# 154  [{'Value': 'c30810846f52a8cefd4512b63348be5f',...
# 155  [{'Value': '165d1a5730c67da3238fa28c9c7f1076',...
#
#                                            ContentDate  \
# 0    {'Start': '2022-05-03T00:01:39.024000Z', 'End'...
# 1    {'Start': '2022-05-03T00:01:39.024000Z', 'End'...
# 2    {'Start': '2022-05-03T00:01:39.024000Z', 'End'...
# 3    {'Start': '2022-05-03T00:01:39.024000Z', 'End'...
# 4    {'Start': '2022-05-03T00:01:39.024000Z', 'End'...
# ..                                                 ...
# 151  {'Start': '2022-05-03T00:01:39.024000Z', 'End'...
# 152  {'Start': '2022-05-03T00:01:39.024000Z', 'End'...
# 153  {'Start': '2022-05-03T00:01:39.024000Z', 'End'...
# 154  {'Start': '2022-05-03T00:01:39.024000Z', 'End'...
# 155  {'Start': '2022-05-03T00:01:39.024000Z', 'End'...
#
#                                              Footprint  \
# 0    geography'SRID=4326;POLYGON ((-123.37811606469...
# 1    geography'SRID=4326;POLYGON ((-135.00128035426...
# 2    geography'SRID=4326;POLYGON ((-140.96097336164...
# 3    geography'SRID=4326;POLYGON ((-123.00128035426...
# 4    geography'SRID=4326;POLYGON ((-140.96097336164...
# ..                                                 ...
# 151  geography'SRID=4326;POLYGON ((-140.77883895807...
# 152  geography'SRID=4326;POLYGON ((-116.48997853732...
# 153  geography'SRID=4326;POLYGON ((-117.28586000606...
# 154  geography'SRID=4326;POLYGON ((-141.78746379933...
# 155  geography'SRID=4326;POLYGON ((-140.45053600549...
#
#                                           GeoFootprint  \
# 0    {'type': 'Polygon', 'coordinates': [[[-123.378...
# 1    {'type': 'Polygon', 'coordinates': [[[-135.001...
# 2    {'type': 'Polygon', 'coordinates': [[[-140.960...
# 3    {'type': 'Polygon', 'coordinates': [[[-123.001...
# 4    {'type': 'Polygon', 'coordinates': [[[-140.960...
# ..                                                 ...
# 151  {'type': 'Polygon', 'coordinates': [[[-140.778...
# 152  {'type': 'Polygon', 'coordinates': [[[-116.489...
# 153  {'type': 'Polygon', 'coordinates': [[[-117.285...
# 154  {'type': 'Polygon', 'coordinates': [[[-141.787...
# 155  {'type': 'Polygon', 'coordinates': [[[-140.450...
#
#                                             Attributes id_original_query  \
# 0    [{'@odata.type': '#OData.CSC.StringAttribute',...             test1
# 1    [{'@odata.type': '#OData.CSC.StringAttribute',...             test1
# 2    [{'@odata.type': '#OData.CSC.StringAttribute',...             test1
# 3    [{'@odata.type': '#OData.CSC.StringAttribute',...             test1
# 4    [{'@odata.type': '#OData.CSC.StringAttribute',...             test1
# ..                                                 ...               ...
# 151  [{'@odata.type': '#OData.CSC.StringAttribute',...             test2
# 152  [{'@odata.type': '#OData.CSC.StringAttribute',...             test2
# 153  [{'@odata.type': '#OData.CSC.StringAttribute',...             test2
# 154  [{'@odata.type': '#OData.CSC.StringAttribute',...             test2
# 155  [{'@odata.type': '#OData.CSC.StringAttribute',...             test2
#
#                                               geometry
# 0    POLYGON ((-123.37812 81.90748, -122.69284 80.9...
# 1    POLYGON ((-135.00128 81.95692, -135.00114 80.9...
# 2    POLYGON ((-140.96097 80.97292, -134.75703 80.9...
# 3    POLYGON ((-123.00128 81.95692, -123.00114 80.9...
# 4    POLYGON ((-140.96097 80.97292, -134.75703 80.9...
# ..                                                 ...
# 151  POLYGON ((-140.77884 80.92048, -140.75703 80.9...
# 152  POLYGON ((-116.48998 80.12639, -116.48817 80.1...
# 153  POLYGON ((-117.28586 80.11698, -123.00105 80.1...
# 154  POLYGON ((-141.78746 81.82497, -140.08085 81.8...
# 155  POLYGON ((-140.45054 80.82657, -140.43739 81.0...
#
# [156 rows x 18 columns]

# %%
counts
# Out:
# id_original_query
# test1    78
# test2    78
# Name: count, dtype: int64

# %% [markdown]
# ## we can check that product IDs are exatcly the same

# %%
cpt_common = 0
cpt_uncommon = 0
total = 0
for uu in result[result['id_original_query']=='test1']['Id']:
    total += 1
    is_comon = False
    for vv in result[result['id_original_query']=='test2']['Id']:
        if uu==vv:
            # print('bingo')
            is_comon = True
    if is_comon is True:
        cpt_common += 1
    else:
        cpt_uncommon += 1
        # print(uu)
print('cpt_common',cpt_common,'/',total)
print('cpt_uncommon',cpt_uncommon,'/',total)
# Out:
# cpt_common 78 / 78
# cpt_uncommon 0 / 78

# %% [markdown]
#  doing the same query with a single 'id_query' returns a DataFrame with 78 lines instead of 156

# %%
gdf_unique_id = gpd.GeoDataFrame(
        {
            "start_datetime": [
                np.datetime64("2022-05-03 00:00:00"),
            ],
            "end_datetime": [
                np.datetime64("2022-05-03 00:02:00"),
            ],
            "geometry": [None],
            "collection": ["SENTINEL-2"],
            "name": [None],
            "sensormode": [None],
            "producttype": [None],
            "Attributes": [None],
            "id_query": ["test1"],
        }
    )
result_2 = qr.fetch_data(gdf=gdf_unique_id, top=1000)
result_2.head()
# Out:
#      @odata.mediaContentType                                    Id  \
# 77  application/octet-stream  7b561bb5-bb5c-476a-ac51-d361cace788d
# 24  application/octet-stream  f05036fd-66ee-42bb-a12f-92b319f4c7fb
# 76  application/octet-stream  b2f271b3-0217-4dcd-93b3-29ceb81b78f1
# 75  application/octet-stream  9501c4d2-4315-4033-8fc0-6ffdb6ed0a8a
# 0   application/octet-stream  6b7817c3-a120-4c1b-9d00-672249307e85
#
#                                                  Name  \
# 77  S2B_MSIL2A_20220503T000139_N0510_R016_T11XML_2...
# 24  S2B_MSIL2A_20220503T000139_N0510_R016_T08XNR_2...
# 76  S2B_MSIL1C_20220503T000139_N0510_R016_T07XEL_2...
# 75  S2B_MSIL2A_20220503T000139_N0510_R016_T10XER_2...
# 0   S2B_MSIL2A_20220503T000139_N0510_R016_T07XEL_2...
#
#                  ContentType  ContentLength                   OriginDate  \
# 77  application/octet-stream      905950656  2024-10-22T03:57:01.163000Z
# 24  application/octet-stream      906648145  2024-10-22T03:56:59.617000Z
# 76  application/octet-stream      739061869  2024-10-22T03:56:56.046000Z
# 75  application/octet-stream      906168896  2024-10-22T03:57:00.756000Z
# 0   application/octet-stream      899169465  2024-10-22T03:56:59.076000Z
#
#                 PublicationDate             ModificationDate  Online  \
# 77  2024-11-30T10:52:42.448541Z  2024-11-30T10:52:58.857924Z    True
# 24  2024-11-30T10:52:13.209895Z  2024-11-30T10:52:24.656867Z    True
# 76  2024-11-30T10:51:43.843079Z  2024-11-30T10:51:54.844138Z    True
# 75  2024-11-30T10:51:41.950143Z  2024-11-30T10:51:53.955437Z    True
# 0   2024-11-30T10:51:11.639296Z  2024-11-30T10:51:22.361116Z    True
#
#                    EvictionDate  \
# 77  9999-12-31T23:59:59.999999Z
# 24  9999-12-31T23:59:59.999999Z
# 76  9999-12-31T23:59:59.999999Z
# 75  9999-12-31T23:59:59.999999Z
# 0   9999-12-31T23:59:59.999999Z
#
#                                                S3Path  \
# 77  /eodata/Sentinel-2/MSI/L2A_N0500/2022/05/03/S2...
# 24  /eodata/Sentinel-2/MSI/L2A_N0500/2022/05/03/S2...
# 76  /eodata/Sentinel-2/MSI/L1C_N0500/2022/05/03/S2...
# 75  /eodata/Sentinel-2/MSI/L2A_N0500/2022/05/03/S2...
# 0   /eodata/Sentinel-2/MSI/L2A_N0500/2022/05/03/S2...
#
#                                              Checksum  \
# 77  [{'Value': '8dc89dabd44eb3869de612042a6a427d',...
# 24  [{'Value': '8e855e16387253f7aca2fcf38b0d85fb',...
# 76  [{'Value': 'f514d8376518117f2e345263982d4ec1',...
# 75  [{'Value': '6ee6c35e7a4fb8ad3913279ad053d32a',...
# 0   [{'Value': 'a54d86f0a52c6588bcc1fd581a8d2b42',...
#
#                                           ContentDate  \
# 77  {'Start': '2022-05-03T00:01:39.024000Z', 'End'...
# 24  {'Start': '2022-05-03T00:01:39.024000Z', 'End'...
# 76  {'Start': '2022-05-03T00:01:39.024000Z', 'End'...
# 75  {'Start': '2022-05-03T00:01:39.024000Z', 'End'...
# 0   {'Start': '2022-05-03T00:01:39.024000Z', 'End'...
#
#                                             Footprint  \
# 77  geography'SRID=4326;POLYGON ((-123.37811606469...
# 24  geography'SRID=4326;POLYGON ((-135.00128035426...
# 76  geography'SRID=4326;POLYGON ((-140.96097336164...
# 75  geography'SRID=4326;POLYGON ((-123.00128035426...
# 0   geography'SRID=4326;POLYGON ((-140.96097336164...
#
#                                          GeoFootprint  \
# 77  {'type': 'Polygon', 'coordinates': [[[-123.378...
# 24  {'type': 'Polygon', 'coordinates': [[[-135.001...
# 76  {'type': 'Polygon', 'coordinates': [[[-140.960...
# 75  {'type': 'Polygon', 'coordinates': [[[-123.001...
# 0   {'type': 'Polygon', 'coordinates': [[[-140.960...
#
#                                            Attributes id_original_query  \
# 77  [{'@odata.type': '#OData.CSC.StringAttribute',...             test1
# 24  [{'@odata.type': '#OData.CSC.StringAttribute',...             test1
# 76  [{'@odata.type': '#OData.CSC.StringAttribute',...             test1
# 75  [{'@odata.type': '#OData.CSC.StringAttribute',...             test1
# 0   [{'@odata.type': '#OData.CSC.StringAttribute',...             test1
#
#                                              geometry
# 77  POLYGON ((-123.37812 81.90748, -122.69284 80.9...
# 24  POLYGON ((-135.00128 81.95692, -135.00114 80.9...
# 76  POLYGON ((-140.96097 80.97292, -134.75703 80.9...
# 75  POLYGON ((-123.00128 81.95692, -123.00114 80.9...
# 0   POLYGON ((-140.96097 80.97292, -134.75703 80.9...

# %% [markdown]
# When there is multiple "id_query", the input GeoDataFrame is split/group-by into smaller GeoDataFrame with identical "id_query".
#
# Setting carefully the "id_query" column in the input GeoDataFrame is important because it impacts the number of queries and the output returned.
#
# In most of the case the 'id_query' column can be filled with a unique value, but for some cases, for instance when co-locating a set of moored buoys with Sentinel products, the user needs the exhaustive list of Sentinel products per location and he also needs to be able to separate the results per location (i.e. buoys).
