# %%
import cdsodatacli.query as qr
import logging
import requests
import pandas as pd
import datetime 
import time


from importlib import reload
reload(logging)
logging.basicConfig(level=logging.DEBUG)

# %% [markdown]
# # To search for products containing “S1A” in their names:

# %%
json = requests.get("https://catalogue.dataspace.copernicus.eu/odata/v1/Products?$filter=Collection/Name eq 'SENTINEL-2' and ContentDate/Start gt 2022-05-03T00:00:00.000Z and ContentDate/Start lt 2022-05-03T00:11:00.000Z&$top=1000").json()
df = pd.DataFrame.from_dict(json['value'])

df['Name']
# Out:
# 0      S2B_OPER_AUX_GNSSRD_POD__20220510T031816_V2022...
# 1      S2A_OPER_AUX_GNSSRD_POD__20220510T030151_V2022...
# 2      S2B_MSIL2A_20220503T000139_N0400_R016_T08XMQ_2...
# 3      S2B_MSIL1C_20220503T000139_N0400_R016_T09XWM_2...
# 4      S2B_MSIL2A_20220503T000139_N0400_R016_T09XWM_2...
#                              ...
# 321    S2B_MSIL2A_20220503T000609_N0400_R016_T01WFV_2...
# 322    S2B_MSIL2A_20220503T000609_N0400_R016_T01WCV_2...
# 323    S2B_MSIL2A_20220503T000609_N0400_R016_T58VEH_2...
# 324    S2B_MSIL2A_20220503T000609_N0400_R016_T59VMC_2...
# 325    S2B_MSIL2A_20220503T000609_N0400_R016_T01WCP_2...
# Name: Name, Length: 326, dtype: object

# %%
data_gdf = qr.fetch_data(collection='SENTINEL-2', start_datetime='2022-05-03 00:00:00', end_datetime='2022-05-03 00:11:00', top=1000)
data_gdf
# Out:
# DEBUG:root:normalize_gdf processing time:0.0048449039459228516s
# DEBUG:root:creat_urls processing time:0.00032138824462890625s
# DEBUG:root:[(0, "https://catalogue.dataspace.copernicus.eu/odata/v1/Products?$filter=Collection/Name eq 'SENTINEL-2' and ContentDate/Start gt 2022-05-03T00:00:00.000Z and ContentDate/Start lt 2022-05-03T00:11:00.000Z&$top=1000&$expand=Attributes")]
# 100%|█████████████████████████████████████████████| 1/1 [00:00<00:00, 88.15it/s]
# DEBUG:root:      @odata.mediaContentType                                    Id  \
# 0    application/octet-stream  b2ac733d-efa4-49e9-9edc-fb37e2a7f938
# 1    application/octet-stream  a449f701-d29a-4ce9-b838-33061ee1d573
# 2    application/octet-stream  7e0f9557-d537-56bb-90a1-9b4a746f0f55
# 3    application/octet-stream  7f845cba-66f7-5ba2-88f2-910915b2234a
# 4    application/octet-stream  8bc6bacd-7b47-52ea-9c36-cbb09fc83af1
# ..                        ...                                   ...
# 321  application/octet-stream  7962cb91-2fc9-5008-8a47-a52afb010c60
# 322  application/octet-stream  9fe39112-9935-5d0b-b658-6f37fb5a0fe8
# 323  application/octet-stream  f3d7ff06-9321-51e1-8356-8ebc5cd5830e
# 324  application/octet-stream  9c658a54-98db-546e-b317-b38b2ca85f53
# 325  application/octet-stream  67591e82-c8fb-5809-b411-a843c9b86b20
#
#                                                   Name  \
# 0    S2B_OPER_AUX_GNSSRD_POD__20220510T031816_V2022...
# 1    S2A_OPER_AUX_GNSSRD_POD__20220510T030151_V2022...
# 2    S2B_MSIL2A_20220503T000139_N0400_R016_T08XMQ_2...
# 3    S2B_MSIL1C_20220503T000139_N0400_R016_T09XWM_2...
# 4    S2B_MSIL2A_20220503T000139_N0400_R016_T09XWM_2...
# ..                                                 ...
# 321  S2B_MSIL2A_20220503T000609_N0400_R016_T01WFV_2...
# 322  S2B_MSIL2A_20220503T000609_N0400_R016_T01WCV_2...
# 323  S2B_MSIL2A_20220503T000609_N0400_R016_T58VEH_2...
# 324  S2B_MSIL2A_20220503T000609_N0400_R016_T59VMC_2...
# 325  S2B_MSIL2A_20220503T000609_N0400_R016_T01WCP_2...
#
#                   ContentType  ContentLength                OriginDate  \
# 0    application/octet-stream        2650202  2022-05-10T03:32:10.993Z
# 1    application/octet-stream        2281403  2022-05-10T03:32:11.048Z
# 2    application/octet-stream              0  2022-05-03T03:11:09.519Z
# 3    application/octet-stream              0  2022-05-03T01:46:08.451Z
# 4    application/octet-stream              0  2022-05-03T03:07:32.962Z
# ..                        ...            ...                       ...
# 321  application/octet-stream              0  2022-05-03T05:30:18.289Z
# 322  application/octet-stream              0  2022-05-03T05:33:12.115Z
# 323  application/octet-stream              0  2022-05-03T04:40:21.670Z
# 324  application/octet-stream              0  2022-05-03T04:45:48.042Z
# 325  application/octet-stream              0  2022-05-03T05:29:00.525Z
#
#               PublicationDate          ModificationDate  Online EvictionDate  \
# 0    2023-10-25T13:45:42.483Z  2023-10-25T13:45:42.483Z    True
# 1    2023-10-25T13:45:41.052Z  2023-10-25T13:45:41.052Z    True
# 2    2022-05-03T03:15:23.316Z  2022-05-03T03:15:23.316Z    True
# 3    2022-05-03T01:45:31.042Z  2022-05-03T01:45:31.042Z    True
# 4    2022-05-03T03:13:05.707Z  2022-05-03T03:13:05.707Z    True
# ..                        ...                       ...     ...          ...
# 321  2022-05-03T05:32:57.334Z  2022-05-03T05:32:57.334Z    True
# 322  2022-05-03T05:38:13.912Z  2022-05-03T05:38:13.912Z    True
# 323  2022-05-03T04:45:51.514Z  2022-05-03T04:45:51.514Z    True
# 324  2022-05-03T04:45:43.469Z  2022-05-03T04:45:43.469Z    True
# 325  2022-05-03T05:33:14.236Z  2022-05-03T05:33:14.236Z    True
#
#                                                 S3Path Checksum  \
# 0    /eodata/Sentinel-2/AUX/AUX_GNSSRD/2022/05/03/S...     [{}]
# 1    /eodata/Sentinel-2/AUX/AUX_GNSSRD/2022/05/03/S...     [{}]
# 2    /eodata/Sentinel-2/MSI/L2A/2022/05/03/S2B_MSIL...       []
# 3    /eodata/Sentinel-2/MSI/L1C/2022/05/03/S2B_MSIL...       []
# 4    /eodata/Sentinel-2/MSI/L2A/2022/05/03/S2B_MSIL...       []
# ..                                                 ...      ...
# 321  /eodata/Sentinel-2/MSI/L2A/2022/05/03/S2B_MSIL...       []
# 322  /eodata/Sentinel-2/MSI/L2A/2022/05/03/S2B_MSIL...       []
# 323  /eodata/Sentinel-2/MSI/L2A/2022/05/03/S2B_MSIL...       []
# 324  /eodata/Sentinel-2/MSI/L2A/2022/05/03/S2B_MSIL...       []
# 325  /eodata/Sentinel-2/MSI/L2A/2022/05/03/S2B_MSIL...       []
#
#                                            ContentDate  \
# 0    {'Start': '2022-05-03T00:00:04.000Z', 'End': '...
# 1    {'Start': '2022-05-03T00:00:07.000Z', 'End': '...
# 2    {'Start': '2022-05-03T00:01:39.024Z', 'End': '...
# 3    {'Start': '2022-05-03T00:01:39.024Z', 'End': '...
# 4    {'Start': '2022-05-03T00:01:39.024Z', 'End': '...
# ..                                                 ...
# 321  {'Start': '2022-05-03T00:06:09.024Z', 'End': '...
# 322  {'Start': '2022-05-03T00:06:09.024Z', 'End': '...
# 323  {'Start': '2022-05-03T00:06:09.024Z', 'End': '...
# 324  {'Start': '2022-05-03T00:06:09.024Z', 'End': '...
# 325  {'Start': '2022-05-03T00:06:09.024Z', 'End': '...
#
#                                              Footprint  \
# 0                                                 None
# 1                                                 None
# 2    geography'SRID=4326;POLYGON ((-138.24152 80.05...
# 3    geography'SRID=4326;POLYGON ((-129.00139 82.52...
# 4    geography'SRID=4326;POLYGON ((-129.00139 82.52...
# ..                                                 ...
# 321  geography'SRID=4326;POLYGON ((-173.96036 71.22...
# 322  geography'SRID=4326;MULTIPOLYGON (((180 71.087...
# 323  geography'SRID=4326;POLYGON ((165.07266642521 ...
# 324  geography'SRID=4326;POLYGON ((170.66444556029 ...
# 325  geography'SRID=4326;POLYGON ((179.61591050406 ...
#
#                                           GeoFootprint  \
# 0                                                 None
# 1                                                 None
# 2    {'type': 'Polygon', 'coordinates': [[[-138.241...
# 3    {'type': 'Polygon', 'coordinates': [[[-129.001...
# 4    {'type': 'Polygon', 'coordinates': [[[-129.001...
# ..                                                 ...
# 321  {'type': 'Polygon', 'coordinates': [[[-173.960...
# 322  {'type': 'MultiPolygon', 'coordinates': [[[[18...
# 323  {'type': 'Polygon', 'coordinates': [[[165.0726...
# 324  {'type': 'Polygon', 'coordinates': [[[170.6644...
# 325  {'type': 'Polygon', 'coordinates': [[[179.6159...
#
#                                             Attributes  input_index
# 0    [{'@odata.type': '#OData.CSC.StringAttribute',...            0
# 1    [{'@odata.type': '#OData.CSC.StringAttribute',...            0
# 2    [{'@odata.type': '#OData.CSC.StringAttribute',...            0
# 3    [{'@odata.type': '#OData.CSC.StringAttribute',...            0
# 4    [{'@odata.type': '#OData.CSC.StringAttribute',...            0
# ..                                                 ...          ...
# 321  [{'@odata.type': '#OData.CSC.StringAttribute',...            0
# 322  [{'@odata.type': '#OData.CSC.StringAttribute',...            0
# 323  [{'@odata.type': '#OData.CSC.StringAttribute',...            0
# 324  [{'@odata.type': '#OData.CSC.StringAttribute',...            0
# 325  [{'@odata.type': '#OData.CSC.StringAttribute',...            0
#
# [326 rows x 17 columns]
# DEBUG:root:remove_duplicates time: 0.0012688636779785156s
#       @odata.mediaContentType                                    Id  \
# 0    application/octet-stream  b2ac733d-efa4-49e9-9edc-fb37e2a7f938
# 1    application/octet-stream  a449f701-d29a-4ce9-b838-33061ee1d573
# 2    application/octet-stream  7e0f9557-d537-56bb-90a1-9b4a746f0f55
# 3    application/octet-stream  7f845cba-66f7-5ba2-88f2-910915b2234a
# 4    application/octet-stream  8bc6bacd-7b47-52ea-9c36-cbb09fc83af1
# ..                        ...                                   ...
# 321  application/octet-stream  7962cb91-2fc9-5008-8a47-a52afb010c60
# 322  application/octet-stream  9fe39112-9935-5d0b-b658-6f37fb5a0fe8
# 323  application/octet-stream  f3d7ff06-9321-51e1-8356-8ebc5cd5830e
# 324  application/octet-stream  9c658a54-98db-546e-b317-b38b2ca85f53
# 325  application/octet-stream  67591e82-c8fb-5809-b411-a843c9b86b20
#
#                                                   Name  \
# 0    S2B_OPER_AUX_GNSSRD_POD__20220510T031816_V2022...
# 1    S2A_OPER_AUX_GNSSRD_POD__20220510T030151_V2022...
# 2    S2B_MSIL2A_20220503T000139_N0400_R016_T08XMQ_2...
# 3    S2B_MSIL1C_20220503T000139_N0400_R016_T09XWM_2...
# 4    S2B_MSIL2A_20220503T000139_N0400_R016_T09XWM_2...
# ..                                                 ...
# 321  S2B_MSIL2A_20220503T000609_N0400_R016_T01WFV_2...
# 322  S2B_MSIL2A_20220503T000609_N0400_R016_T01WCV_2...
# 323  S2B_MSIL2A_20220503T000609_N0400_R016_T58VEH_2...
# 324  S2B_MSIL2A_20220503T000609_N0400_R016_T59VMC_2...
# 325  S2B_MSIL2A_20220503T000609_N0400_R016_T01WCP_2...
#
#                   ContentType  ContentLength                OriginDate  \
# 0    application/octet-stream        2650202  2022-05-10T03:32:10.993Z
# 1    application/octet-stream        2281403  2022-05-10T03:32:11.048Z
# 2    application/octet-stream              0  2022-05-03T03:11:09.519Z
# 3    application/octet-stream              0  2022-05-03T01:46:08.451Z
# 4    application/octet-stream              0  2022-05-03T03:07:32.962Z
# ..                        ...            ...                       ...
# 321  application/octet-stream              0  2022-05-03T05:30:18.289Z
# 322  application/octet-stream              0  2022-05-03T05:33:12.115Z
# 323  application/octet-stream              0  2022-05-03T04:40:21.670Z
# 324  application/octet-stream              0  2022-05-03T04:45:48.042Z
# 325  application/octet-stream              0  2022-05-03T05:29:00.525Z
#
#               PublicationDate          ModificationDate  Online EvictionDate  \
# 0    2023-10-25T13:45:42.483Z  2023-10-25T13:45:42.483Z    True
# 1    2023-10-25T13:45:41.052Z  2023-10-25T13:45:41.052Z    True
# 2    2022-05-03T03:15:23.316Z  2022-05-03T03:15:23.316Z    True
# 3    2022-05-03T01:45:31.042Z  2022-05-03T01:45:31.042Z    True
# 4    2022-05-03T03:13:05.707Z  2022-05-03T03:13:05.707Z    True
# ..                        ...                       ...     ...          ...
# 321  2022-05-03T05:32:57.334Z  2022-05-03T05:32:57.334Z    True
# 322  2022-05-03T05:38:13.912Z  2022-05-03T05:38:13.912Z    True
# 323  2022-05-03T04:45:51.514Z  2022-05-03T04:45:51.514Z    True
# 324  2022-05-03T04:45:43.469Z  2022-05-03T04:45:43.469Z    True
# 325  2022-05-03T05:33:14.236Z  2022-05-03T05:33:14.236Z    True
#
#                                                 S3Path Checksum  \
# 0    /eodata/Sentinel-2/AUX/AUX_GNSSRD/2022/05/03/S...     [{}]
# 1    /eodata/Sentinel-2/AUX/AUX_GNSSRD/2022/05/03/S...     [{}]
# 2    /eodata/Sentinel-2/MSI/L2A/2022/05/03/S2B_MSIL...       []
# 3    /eodata/Sentinel-2/MSI/L1C/2022/05/03/S2B_MSIL...       []
# 4    /eodata/Sentinel-2/MSI/L2A/2022/05/03/S2B_MSIL...       []
# ..                                                 ...      ...
# 321  /eodata/Sentinel-2/MSI/L2A/2022/05/03/S2B_MSIL...       []
# 322  /eodata/Sentinel-2/MSI/L2A/2022/05/03/S2B_MSIL...       []
# 323  /eodata/Sentinel-2/MSI/L2A/2022/05/03/S2B_MSIL...       []
# 324  /eodata/Sentinel-2/MSI/L2A/2022/05/03/S2B_MSIL...       []
# 325  /eodata/Sentinel-2/MSI/L2A/2022/05/03/S2B_MSIL...       []
#
#                                            ContentDate  \
# 0    {'Start': '2022-05-03T00:00:04.000Z', 'End': '...
# 1    {'Start': '2022-05-03T00:00:07.000Z', 'End': '...
# 2    {'Start': '2022-05-03T00:01:39.024Z', 'End': '...
# 3    {'Start': '2022-05-03T00:01:39.024Z', 'End': '...
# 4    {'Start': '2022-05-03T00:01:39.024Z', 'End': '...
# ..                                                 ...
# 321  {'Start': '2022-05-03T00:06:09.024Z', 'End': '...
# 322  {'Start': '2022-05-03T00:06:09.024Z', 'End': '...
# 323  {'Start': '2022-05-03T00:06:09.024Z', 'End': '...
# 324  {'Start': '2022-05-03T00:06:09.024Z', 'End': '...
# 325  {'Start': '2022-05-03T00:06:09.024Z', 'End': '...
#
#                                              Footprint  \
# 0                                                 None
# 1                                                 None
# 2    geography'SRID=4326;POLYGON ((-138.24152 80.05...
# 3    geography'SRID=4326;POLYGON ((-129.00139 82.52...
# 4    geography'SRID=4326;POLYGON ((-129.00139 82.52...
# ..                                                 ...
# 321  geography'SRID=4326;POLYGON ((-173.96036 71.22...
# 322  geography'SRID=4326;MULTIPOLYGON (((180 71.087...
# 323  geography'SRID=4326;POLYGON ((165.07266642521 ...
# 324  geography'SRID=4326;POLYGON ((170.66444556029 ...
# 325  geography'SRID=4326;POLYGON ((179.61591050406 ...
#
#                                           GeoFootprint  \
# 0                                                 None
# 1                                                 None
# 2    {'type': 'Polygon', 'coordinates': [[[-138.241...
# 3    {'type': 'Polygon', 'coordinates': [[[-129.001...
# 4    {'type': 'Polygon', 'coordinates': [[[-129.001...
# ..                                                 ...
# 321  {'type': 'Polygon', 'coordinates': [[[-173.960...
# 322  {'type': 'MultiPolygon', 'coordinates': [[[[18...
# 323  {'type': 'Polygon', 'coordinates': [[[165.0726...
# 324  {'type': 'Polygon', 'coordinates': [[[170.6644...
# 325  {'type': 'Polygon', 'coordinates': [[[179.6159...
#
#                                             Attributes  input_index
# 0    [{'@odata.type': '#OData.CSC.StringAttribute',...            0
# 1    [{'@odata.type': '#OData.CSC.StringAttribute',...            0
# 2    [{'@odata.type': '#OData.CSC.StringAttribute',...            0
# 3    [{'@odata.type': '#OData.CSC.StringAttribute',...            0
# 4    [{'@odata.type': '#OData.CSC.StringAttribute',...            0
# ..                                                 ...          ...
# 321  [{'@odata.type': '#OData.CSC.StringAttribute',...            0
# 322  [{'@odata.type': '#OData.CSC.StringAttribute',...            0
# 323  [{'@odata.type': '#OData.CSC.StringAttribute',...            0
# 324  [{'@odata.type': '#OData.CSC.StringAttribute',...            0
# 325  [{'@odata.type': '#OData.CSC.StringAttribute',...            0
#
# [326 rows x 17 columns]

# %%
json = requests.get("https://catalogue.dataspace.copernicus.eu/odata/v1/Products?$filter=OData.CSC.Intersects(area=geography'SRID=4326;POLYGON((12.655118166047592 47.44667197521409, 21.39065656328509 48.347694733853245, 28.334291357162826 41.877123516783655, 17.47086198383573 40.35854475076158, 12.655118166047592 47.44667197521409))') and ContentDate/Start gt 2022-05-20T00:00:00.000Z and ContentDate/Start lt 2022-05-21T00:00:00.000Z&$top=1000").json()
                     
df1 = pd.DataFrame.from_dict(json['value'])
df1
# Out:
#       @odata.mediaContentType                                    Id  \
# 0    application/octet-stream  c9e0e178-29e6-4c44-bc0c-ee805de7be19
# 1    application/octet-stream  0d3b8cf1-01fb-5f7e-820a-1d5442875575
# 2    application/octet-stream  d3b5fbd9-9ffd-579b-b327-4de3e8502591
# 3    application/octet-stream  0bfcd52a-1c10-5870-820a-7282032fe8e4
# 4    application/octet-stream  c23f376c-6a5f-5faf-9399-9a5544b83d5b
# ..                        ...                                   ...
# 484  application/octet-stream  9d2f1f49-721d-529c-968a-67ad9964a590
# 485  application/octet-stream  665b4859-4354-5d0b-8cca-9adb7573d2d6
# 486  application/octet-stream  103633b7-6312-5301-84c1-db0808544224
# 487  application/octet-stream  88d84079-d56f-51f6-bbc2-2ddf2b59aea0
# 488  application/octet-stream  ffee6c4a-92fd-5db4-ae0b-df1b85eb555b
#
#                                                   Name  \
# 0    S5P_RPRO_L1B_RA_BD1_20220520T110145_20220520T1...
# 1             LC08_L1TP_180031_20220520_20220520_02_RT
# 2             LC08_L2SP_180031_20220520_20220525_02_T1
# 3             LC08_L1TP_180031_20220520_20220525_02_T1
# 4    S1A_IW_RAW__0SDV_20220520T163348_20220520T1634...
# ..                                                 ...
# 484  SM_OPER_MIR_SMUDP2_20220520T173708_20220520T18...
# 485  S3A_SY_2_SYN____20220520T091324_20220520T09162...
# 486  SM_OPER_MIR_SCLF1C_20220520T032623_20220520T04...
# 487  SM_OPER_MIR_BWLF1C_20220520T155703_20220520T16...
# 488  S6A_P4_2__LR______20220520T155810_20220520T165...
#
#                   ContentType  ContentLength                OriginDate  \
# 0    application/octet-stream      698580216  2023-03-24T23:02:05.922Z
# 1    application/octet-stream              0  2022-05-20T08:45:20.510Z
# 2    application/octet-stream              0  2022-05-20T08:45:20.510Z
# 3    application/octet-stream              0  2022-05-20T08:45:20.510Z
# 4    application/octet-stream              0  2022-05-20T18:00:24.540Z
# ..                        ...            ...                       ...
# 484  application/octet-stream              0  2022-05-21T00:30:47.000Z
# 485  application/octet-stream              0  2022-05-22T10:05:03.519Z
# 486  application/octet-stream              0  2022-05-20T10:05:49.000Z
# 487  application/octet-stream              0  2022-05-20T23:37:26.000Z
# 488  application/octet-stream              0  2022-05-21T09:57:49.000Z
#
#               PublicationDate          ModificationDate  Online EvictionDate  \
# 0    2023-05-15T22:18:17.975Z  2023-10-23T19:31:23.174Z    True
# 1    2022-05-22T08:08:13.816Z  2022-05-22T08:08:13.816Z    True
# 2    2022-05-27T12:43:58.554Z  2022-05-27T12:43:58.554Z    True
# 3    2022-05-27T15:38:46.726Z  2022-05-27T15:38:46.726Z    True
# 4    2022-05-20T18:06:35.339Z  2022-05-20T18:06:35.339Z    True
# ..                        ...                       ...     ...          ...
# 484  2022-05-21T00:54:38.836Z  2022-05-21T00:54:38.836Z    True
# 485  2022-05-22T10:12:23.216Z  2022-05-22T10:12:23.216Z    True
# 486  2022-05-20T10:19:34.979Z  2022-05-20T10:19:34.979Z    True
# 487  2022-05-20T23:53:50.539Z  2022-05-20T23:53:50.539Z    True
# 488  2022-05-21T11:10:35.580Z  2022-05-21T11:10:35.580Z    True
#
#                                                 S3Path  \
# 0    /eodata/Sentinel-5P/TROPOMI/L1B/2022/05/20/S5P...
# 1    /eodata/Landsat-8/OLI_TIRS/L1TP/2022/05/20/LC0...
# 2    /eodata/Landsat-8/OLI_TIRS/L2SP/2022/05/20/LC0...
# 3    /eodata/Landsat-8/OLI_TIRS/L1TP/2022/05/20/LC0...
# 4    /eodata/Sentinel-1/SAR/RAW/2022/05/20/S1A_IW_R...
# ..                                                 ...
# 484  /eodata/SMOS/L2SM/MIR_SMUDP2/2022/05/20/SM_OPE...
# 485  /eodata/Sentinel-3/SYNERGY/SY_2_SYN___/2022/05...
# 486  /eodata/SMOS/L1CL/MIR_SCLF1C/2022/05/20/SM_OPE...
# 487  /eodata/SMOS/L1CL/MIR_BWLF1C/2022/05/20/SM_OPE...
# 488  /eodata/Sentinel-6/P4/P4_2__LR_____/2022/05/20...
#
#                                               Checksum  \
# 0    [{'Value': '916176ed523714f544466a05f3b3d642',...
# 1                                                   []
# 2                                                   []
# 3                                                   []
# 4                                                   []
# ..                                                 ...
# 484                                                 []
# 485                                                 []
# 486                                                 []
# 487                                                 []
# 488                                                 []
#
#                                            ContentDate  \
# 0    {'Start': '2022-05-20T11:23:20.000Z', 'End': '...
# 1    {'Start': '2022-05-20T08:45:20.510Z', 'End': '...
# 2    {'Start': '2022-05-20T08:45:20.510Z', 'End': '...
# 3    {'Start': '2022-05-20T08:45:20.510Z', 'End': '...
# 4    {'Start': '2022-05-20T16:33:48.416Z', 'End': '...
# ..                                                 ...
# 484  {'Start': '2022-05-20T17:37:07.159Z', 'End': '...
# 485  {'Start': '2022-05-20T09:13:24.307Z', 'End': '...
# 486  {'Start': '2022-05-20T03:26:22.085Z', 'End': '...
# 487  {'Start': '2022-05-20T15:57:02.280Z', 'End': '...
# 488  {'Start': '2022-05-20T15:58:10.509Z', 'End': '...
#
#                                              Footprint  \
# 0    geography'SRID=4326;POLYGON ((-133.51479 47.45...
# 1    geography'SRID=4326;POLYGON ((27.73522 42.821,...
# 2    geography'SRID=4326;POLYGON ((27.73522 42.821,...
# 3    geography'SRID=4326;POLYGON ((27.73522 42.821,...
# 4    geography'SRID=4326;POLYGON ((21.618 43.6948, ...
# ..                                                 ...
# 484  geography'SRID=4326;POLYGON ((169.61 77.49, 16...
# 485  geography'SRID=4326;POLYGON ((6.90379 41.9685,...
# 486  geography'SRID=4326;MULTIPOLYGON (((180 -83.89...
# 487  geography'SRID=4326;MULTIPOLYGON (((-180 82.66...
# 488  geography'SRID=4326;POLYGON ((-41.006483 66.64...
#
#                                           GeoFootprint
# 0    {'type': 'Polygon', 'coordinates': [[[-133.514...
# 1    {'type': 'Polygon', 'coordinates': [[[27.73522...
# 2    {'type': 'Polygon', 'coordinates': [[[27.73522...
# 3    {'type': 'Polygon', 'coordinates': [[[27.73522...
# 4    {'type': 'Polygon', 'coordinates': [[[21.618, ...
# ..                                                 ...
# 484  {'type': 'Polygon', 'coordinates': [[[169.61, ...
# 485  {'type': 'Polygon', 'coordinates': [[[6.90379,...
# 486  {'type': 'MultiPolygon', 'coordinates': [[[[18...
# 487  {'type': 'MultiPolygon', 'coordinates': [[[[-1...
# 488  {'type': 'Polygon', 'coordinates': [[[-41.0064...
#
# [489 rows x 15 columns]

# %%
data_gdf = qr.fetch_data(geometry='POLYGON((12.655118166047592 47.44667197521409,21.39065656328509 48.347694733853245,28.334291357162826 41.877123516783655,17.47086198383573 40.35854475076158,12.655118166047592 47.44667197521409)), start_datetime='2022-05-20 00:00:00', end_datetime='2022-05-21 00:00:00', top=1000)
data_gdf
# Out:
# DEBUG:root:normalize_gdf processing time:0.0040967464447021484s
# DEBUG:root:creat_urls processing time:0.00028252601623535156s
# 100%|█████████████████████████████████████████████| 1/1 [00:00<00:00, 28.60it/s]
# DEBUG:root:remove_duplicates time: 0.0008251667022705078s
#       @odata.mediaContentType                                    Id  \
# 0    application/octet-stream  c9e0e178-29e6-4c44-bc0c-ee805de7be19
# 1    application/octet-stream  0d3b8cf1-01fb-5f7e-820a-1d5442875575
# 2    application/octet-stream  d3b5fbd9-9ffd-579b-b327-4de3e8502591
# 3    application/octet-stream  0bfcd52a-1c10-5870-820a-7282032fe8e4
# 4    application/octet-stream  c23f376c-6a5f-5faf-9399-9a5544b83d5b
# ..                        ...                                   ...
# 484  application/octet-stream  b519de15-09c9-5353-bddd-2a5245787818
# 485  application/octet-stream  ebd8baaa-7aeb-5466-add4-a1f078ad7e50
# 486  application/octet-stream  e667359a-3c7d-50bf-bd86-c90bdf3f267b
# 487  application/octet-stream  d7cdfa88-dd89-54d2-8dcb-b6468470080e
# 488  application/octet-stream  ebf8798b-5da4-5455-ba1c-90aca9753845
#
#                                                   Name  \
# 0    S5P_RPRO_L1B_RA_BD1_20220520T110145_20220520T1...
# 1             LC08_L1TP_180031_20220520_20220520_02_RT
# 2             LC08_L2SP_180031_20220520_20220525_02_T1
# 3             LC08_L1TP_180031_20220520_20220525_02_T1
# 4    S1A_IW_RAW__0SDV_20220520T163348_20220520T1634...
# ..                                                 ...
# 484  S6A_MW_2__AMR_____20220520T073214_20220520T082...
# 485  S6A_P4_1B_LR______20220520T073214_20220520T082...
# 486  S6A_P4_2__LR______20220520T073214_20220520T082...
# 487  S6A_P4_1B_LR______20220520T155810_20220520T165...
# 488  S6A_MW_2__AMR_____20220520T155810_20220520T165...
#
#                   ContentType  ContentLength                OriginDate  \
# 0    application/octet-stream      698580216  2023-03-24T23:02:05.922Z
# 1    application/octet-stream              0  2022-05-20T08:45:20.510Z
# 2    application/octet-stream              0  2022-05-20T08:45:20.510Z
# 3    application/octet-stream              0  2022-05-20T08:45:20.510Z
# 4    application/octet-stream              0  2022-05-20T18:00:24.540Z
# ..                        ...            ...                       ...
# 484  application/octet-stream              0  2022-05-21T07:34:32.000Z
# 485  application/octet-stream              0  2022-05-21T07:46:13.000Z
# 486  application/octet-stream              0  2022-05-21T08:23:44.000Z
# 487  application/octet-stream              0  2022-05-21T08:03:10.000Z
# 488  application/octet-stream              0  2022-06-13T17:23:53.000Z
#
#               PublicationDate          ModificationDate  Online EvictionDate  \
# 0    2023-05-15T22:18:17.975Z  2023-10-23T19:31:23.174Z    True
# 1    2022-05-22T08:08:13.816Z  2022-05-22T08:08:13.816Z    True
# 2    2022-05-27T12:43:58.554Z  2022-05-27T12:43:58.554Z    True
# 3    2022-05-27T15:38:46.726Z  2022-05-27T15:38:46.726Z    True
# 4    2022-05-20T18:06:35.339Z  2022-05-20T18:06:35.339Z    True
# ..                        ...                       ...     ...          ...
# 484  2022-05-21T07:53:19.946Z  2022-05-21T07:53:19.946Z    True
# 485  2022-05-21T09:57:42.455Z  2022-05-21T09:57:42.455Z    True
# 486  2022-05-21T09:59:14.519Z  2022-05-21T09:59:14.519Z    True
# 487  2022-05-21T10:00:58.434Z  2022-05-21T10:00:58.434Z    True
# 488  2022-06-13T18:28:42.098Z  2022-06-13T18:28:42.098Z    True
#
#                                                 S3Path  \
# 0    /eodata/Sentinel-5P/TROPOMI/L1B/2022/05/20/S5P...
# 1    /eodata/Landsat-8/OLI_TIRS/L1TP/2022/05/20/LC0...
# 2    /eodata/Landsat-8/OLI_TIRS/L2SP/2022/05/20/LC0...
# 3    /eodata/Landsat-8/OLI_TIRS/L1TP/2022/05/20/LC0...
# 4    /eodata/Sentinel-1/SAR/RAW/2022/05/20/S1A_IW_R...
# ..                                                 ...
# 484  /eodata/Sentinel-6/AMR-C/MW_2__AMR____/2022/05...
# 485  /eodata/Sentinel-6/P4/P4_1B_LR_____/2022/05/20...
# 486  /eodata/Sentinel-6/P4/P4_2__LR_____/2022/05/20...
# 487  /eodata/Sentinel-6/P4/P4_1B_LR_____/2022/05/20...
# 488  /eodata/Sentinel-6/AMR-C/MW_2__AMR____/2022/05...
#
#                                               Checksum  \
# 0    [{'Value': '916176ed523714f544466a05f3b3d642',...
# 1                                                   []
# 2                                                   []
# 3                                                   []
# 4                                                   []
# ..                                                 ...
# 484                                                 []
# 485                                                 []
# 486                                                 []
# 487                                                 []
# 488                                                 []
#
#                                            ContentDate  \
# 0    {'Start': '2022-05-20T11:23:20.000Z', 'End': '...
# 1    {'Start': '2022-05-20T08:45:20.510Z', 'End': '...
# 2    {'Start': '2022-05-20T08:45:20.510Z', 'End': '...
# 3    {'Start': '2022-05-20T08:45:20.510Z', 'End': '...
# 4    {'Start': '2022-05-20T16:33:48.416Z', 'End': '...
# ..                                                 ...
# 484  {'Start': '2022-05-20T07:32:14.304Z', 'End': '...
# 485  {'Start': '2022-05-20T07:32:14.511Z', 'End': '...
# 486  {'Start': '2022-05-20T07:32:14.511Z', 'End': '...
# 487  {'Start': '2022-05-20T15:58:10.509Z', 'End': '...
# 488  {'Start': '2022-05-20T15:58:10.263Z', 'End': '...
#
#                                              Footprint  \
# 0    geography'SRID=4326;POLYGON ((-133.51479 47.45...
# 1    geography'SRID=4326;POLYGON ((27.73522 42.821,...
# 2    geography'SRID=4326;POLYGON ((27.73522 42.821,...
# 3    geography'SRID=4326;POLYGON ((27.73522 42.821,...
# 4    geography'SRID=4326;POLYGON ((21.618 43.6948, ...
# ..                                                 ...
# 484  geography'SRID=4326;POLYGON ((32.1621 59.3727,...
# 485  geography'SRID=4326;POLYGON ((-93.566095 -65.6...
# 486  geography'SRID=4326;POLYGON ((-93.566095 -65.6...
# 487  geography'SRID=4326;POLYGON ((-41.006483 66.64...
# 488  geography'SRID=4326;POLYGON ((84.6104 -59.3724...
#
#                                           GeoFootprint  \
# 0    {'type': 'Polygon', 'coordinates': [[[-133.514...
# 1    {'type': 'Polygon', 'coordinates': [[[27.73522...
# 2    {'type': 'Polygon', 'coordinates': [[[27.73522...
# 3    {'type': 'Polygon', 'coordinates': [[[27.73522...
# 4    {'type': 'Polygon', 'coordinates': [[[21.618, ...
# ..                                                 ...
# 484  {'type': 'Polygon', 'coordinates': [[[32.1621,...
# 485  {'type': 'Polygon', 'coordinates': [[[-93.5660...
# 486  {'type': 'Polygon', 'coordinates': [[[-93.5660...
# 487  {'type': 'Polygon', 'coordinates': [[[-41.0064...
# 488  {'type': 'Polygon', 'coordinates': [[[84.6104,...
#
#                                             Attributes  input_index
# 0    [{'@odata.type': '#OData.CSC.IntegerAttribute'...            0
# 1    [{'@odata.type': '#OData.CSC.StringAttribute',...            0
# 2    [{'@odata.type': '#OData.CSC.StringAttribute',...            0
# 3    [{'@odata.type': '#OData.CSC.StringAttribute',...            0
# 4    [{'@odata.type': '#OData.CSC.StringAttribute',...            0
# ..                                                 ...          ...
# 484  [{'@odata.type': '#OData.CSC.StringAttribute',...            0
# 485  [{'@odata.type': '#OData.CSC.StringAttribute',...            0
# 486  [{'@odata.type': '#OData.CSC.StringAttribute',...            0
# 487  [{'@odata.type': '#OData.CSC.StringAttribute',...            0
# 488  [{'@odata.type': '#OData.CSC.StringAttribute',...            0
#
# [489 rows x 17 columns]

# %%
list(df1['Name']) == list(data_gdf['Name'])
# Out:
# False

# %%
json = requests.get("https://catalogue.dataspace.copernicus.eu/odata/v1/Products?$filter=OData.CSC.Intersects(area=geography'SRID=4326;POLYGON((12.655118166047592 47.44667197521409,21.39065656328509 48.347694733853245,28.334291357162826 41.877123516783655,17.47086198383573 40.35854475076158,12.655118166047592 47.44667197521409))') and ContentDate/Start gt 2022-05-20T00:00:00.000Z and ContentDate/Start lt 2022-05-21T00:00:00.000Z&$top=1000").json()
df1 = pd.DataFrame.from_dict(json['value'])
df1
# Out:
#       @odata.mediaContentType                                    Id  \
# 0    application/octet-stream  c9e0e178-29e6-4c44-bc0c-ee805de7be19
# 1    application/octet-stream  0d3b8cf1-01fb-5f7e-820a-1d5442875575
# 2    application/octet-stream  d3b5fbd9-9ffd-579b-b327-4de3e8502591
# 3    application/octet-stream  0bfcd52a-1c10-5870-820a-7282032fe8e4
# 4    application/octet-stream  c23f376c-6a5f-5faf-9399-9a5544b83d5b
# ..                        ...                                   ...
# 484  application/octet-stream  ef1bdcd6-3086-5e68-a81d-0b8dc77477d8
# 485  application/octet-stream  6cc2a03e-3e67-5229-ace4-e83e7c38d440
# 486  application/octet-stream  1278a80b-4243-50b1-9035-84e9f727e87b
# 487  application/octet-stream  665b4859-4354-5d0b-8cca-9adb7573d2d6
# 488  application/octet-stream  e3e29d01-0cfa-45dc-ba88-522a02d3b5e9
#
#                                                   Name  \
# 0    S5P_RPRO_L1B_RA_BD1_20220520T110145_20220520T1...
# 1             LC08_L1TP_180031_20220520_20220520_02_RT
# 2             LC08_L2SP_180031_20220520_20220525_02_T1
# 3             LC08_L1TP_180031_20220520_20220525_02_T1
# 4    S1A_IW_RAW__0SDV_20220520T163348_20220520T1634...
# ..                                                 ...
# 484  S3A_SY_2_AOD____20220520T085813_20220520T09423...
# 485  S3A_SL_2_FRP____20220520T203619_20220520T20391...
# 486  S3A_SY_2_VGP____20220520T085813_20220520T09423...
# 487  S3A_SY_2_SYN____20220520T091324_20220520T09162...
# 488  S5P_RPRO_L1B_RA_BD8_20220520T092015_20220520T1...
#
#                   ContentType  ContentLength                OriginDate  \
# 0    application/octet-stream      698580216  2023-03-24T23:02:05.922Z
# 1    application/octet-stream              0  2022-05-20T08:45:20.510Z
# 2    application/octet-stream              0  2022-05-20T08:45:20.510Z
# 3    application/octet-stream              0  2022-05-20T08:45:20.510Z
# 4    application/octet-stream              0  2022-05-20T18:00:24.540Z
# ..                        ...            ...                       ...
# 484  application/octet-stream              0  2022-05-22T03:00:17.995Z
# 485  application/octet-stream              0  2022-05-22T06:21:01.176Z
# 486  application/octet-stream              0  2022-05-22T09:58:32.637Z
# 487  application/octet-stream              0  2022-05-22T10:05:03.519Z
# 488  application/octet-stream     2149190823  2023-03-24T15:54:43.048Z
#
#               PublicationDate          ModificationDate  Online EvictionDate  \
# 0    2023-05-15T22:18:17.975Z  2023-10-23T19:31:23.174Z    True
# 1    2022-05-22T08:08:13.816Z  2022-05-22T08:08:13.816Z    True
# 2    2022-05-27T12:43:58.554Z  2022-05-27T12:43:58.554Z    True
# 3    2022-05-27T15:38:46.726Z  2022-05-27T15:38:46.726Z    True
# 4    2022-05-20T18:06:35.339Z  2022-05-20T18:06:35.339Z    True
# ..                        ...                       ...     ...          ...
# 484  2022-05-22T03:03:38.780Z  2022-05-22T03:03:38.780Z    True
# 485  2022-05-22T06:26:14.396Z  2022-05-22T06:26:14.396Z    True
# 486  2022-05-22T10:05:03.282Z  2022-05-22T10:05:03.282Z    True
# 487  2022-05-22T10:12:23.216Z  2022-05-22T10:12:23.216Z    True
# 488  2023-05-28T03:38:28.895Z  2023-11-08T12:43:07.401Z    True
#
#                                                 S3Path  \
# 0    /eodata/Sentinel-5P/TROPOMI/L1B/2022/05/20/S5P...
# 1    /eodata/Landsat-8/OLI_TIRS/L1TP/2022/05/20/LC0...
# 2    /eodata/Landsat-8/OLI_TIRS/L2SP/2022/05/20/LC0...
# 3    /eodata/Landsat-8/OLI_TIRS/L1TP/2022/05/20/LC0...
# 4    /eodata/Sentinel-1/SAR/RAW/2022/05/20/S1A_IW_R...
# ..                                                 ...
# 484  /eodata/Sentinel-3/SYNERGY/SY_2_AOD___/2022/05...
# 485  /eodata/Sentinel-3/SLSTR/SL_2_FRP___/2022/05/2...
# 486  /eodata/Sentinel-3/SYNERGY/SY_2_VGP___/2022/05...
# 487  /eodata/Sentinel-3/SYNERGY/SY_2_SYN___/2022/05...
# 488  /eodata/Sentinel-5P/TROPOMI/L1B/2022/05/20/S5P...
#
#                                               Checksum  \
# 0    [{'Value': '916176ed523714f544466a05f3b3d642',...
# 1                                                   []
# 2                                                   []
# 3                                                   []
# 4                                                   []
# ..                                                 ...
# 484                                                 []
# 485                                                 []
# 486                                                 []
# 487                                                 []
# 488  [{'Value': 'b314a71c2da2034f2f4663571c52206f',...
#
#                                            ContentDate  \
# 0    {'Start': '2022-05-20T11:23:20.000Z', 'End': '...
# 1    {'Start': '2022-05-20T08:45:20.510Z', 'End': '...
# 2    {'Start': '2022-05-20T08:45:20.510Z', 'End': '...
# 3    {'Start': '2022-05-20T08:45:20.510Z', 'End': '...
# 4    {'Start': '2022-05-20T16:33:48.416Z', 'End': '...
# ..                                                 ...
# 484  {'Start': '2022-05-20T08:58:12.813Z', 'End': '...
# 485  {'Start': '2022-05-20T20:36:19.006Z', 'End': '...
# 486  {'Start': '2022-05-20T08:58:12.836Z', 'End': '...
# 487  {'Start': '2022-05-20T09:13:24.307Z', 'End': '...
# 488  {'Start': '2022-05-20T09:41:50.000Z', 'End': '...
#
#                                              Footprint  \
# 0    geography'SRID=4326;POLYGON ((-133.51479 47.45...
# 1    geography'SRID=4326;POLYGON ((27.73522 42.821,...
# 2    geography'SRID=4326;POLYGON ((27.73522 42.821,...
# 3    geography'SRID=4326;POLYGON ((27.73522 42.821,...
# 4    geography'SRID=4326;POLYGON ((21.618 43.6948, ...
# ..                                                 ...
# 484  geography'SRID=4326;MULTIPOLYGON (((-180 89.06...
# 485  geography'SRID=4326;POLYGON ((1.90554 51.3226,...
# 486  geography'SRID=4326;MULTIPOLYGON (((-180 89.06...
# 487  geography'SRID=4326;POLYGON ((6.90379 41.9685,...
# 488  geography'SRID=4326;POLYGON ((-108.345146 47.5...
#
#                                           GeoFootprint
# 0    {'type': 'Polygon', 'coordinates': [[[-133.514...
# 1    {'type': 'Polygon', 'coordinates': [[[27.73522...
# 2    {'type': 'Polygon', 'coordinates': [[[27.73522...
# 3    {'type': 'Polygon', 'coordinates': [[[27.73522...
# 4    {'type': 'Polygon', 'coordinates': [[[21.618, ...
# ..                                                 ...
# 484  {'type': 'MultiPolygon', 'coordinates': [[[[-1...
# 485  {'type': 'Polygon', 'coordinates': [[[1.90554,...
# 486  {'type': 'MultiPolygon', 'coordinates': [[[[-1...
# 487  {'type': 'Polygon', 'coordinates': [[[6.90379,...
# 488  {'type': 'Polygon', 'coordinates': [[[-108.345...
#
# [489 rows x 15 columns]

# %%
json = requests.get("https://catalogue.dataspace.copernicus.eu/odata/v1/Products?$filter=OData.CSC.Intersects(area=geography'SRID=4326;POLYGON((12.655118166047592 47.44667197521409,21.39065656328509 48.347694733853245,28.334291357162826 41.877123516783655,17.47086198383573 40.35854475076158,12.655118166047592 47.44667197521409))') and ContentDate/Start gt 2022-05-20T00:00:00.000Z and ContentDate/Start lt 2022-05-21T00:00:00.000Z&$top=1000").json()
df2 = pd.DataFrame.from_dict(json['value'])
df2
# Out:
#       @odata.mediaContentType                                    Id  \
# 0    application/octet-stream  c9e0e178-29e6-4c44-bc0c-ee805de7be19
# 1    application/octet-stream  acb36f7c-b512-339d-b894-55565cf3ee2e
# 2    application/octet-stream  91b6018c-89a5-380f-b4ea-35e91fde9f89
# 3    application/octet-stream  9537426f-8732-5454-8467-9981a2aaf185
# 4    application/octet-stream  28a13728-0e03-5530-ac29-865d57c2a0ae
# ..                        ...                                   ...
# 484  application/octet-stream  ebd8baaa-7aeb-5466-add4-a1f078ad7e50
# 485  application/octet-stream  e667359a-3c7d-50bf-bd86-c90bdf3f267b
# 486  application/octet-stream  d7cdfa88-dd89-54d2-8dcb-b6468470080e
# 487  application/octet-stream  ebf8798b-5da4-5455-ba1c-90aca9753845
# 488  application/octet-stream  074f3794-fe82-55cc-8190-59275c7b5fc5
#
#                                                   Name  \
# 0    S5P_RPRO_L1B_RA_BD1_20220520T110145_20220520T1...
# 1    S3B_SR_2_LAN_HY_20220520T194000_20220520T20101...
# 2    S3A_SR_2_LAN_HY_20220520T090255_20220520T09265...
# 3    S3B_SR_2_WAT____20220520T195350_20220520T20031...
# 4    S3A_SL_2_WST____20220520T203619_20220520T20391...
# ..                                                 ...
# 484  S6A_P4_1B_LR______20220520T073214_20220520T082...
# 485  S6A_P4_2__LR______20220520T073214_20220520T082...
# 486  S6A_P4_1B_LR______20220520T155810_20220520T165...
# 487  S6A_MW_2__AMR_____20220520T155810_20220520T165...
# 488  SM_OPER_MIR_BWSF1C_20220520T155703_20220520T16...
#
#                   ContentType  ContentLength                OriginDate  \
# 0    application/octet-stream      698580216  2023-03-24T23:02:05.922Z
# 1    application/octet-stream       68955538  2023-10-13T09:18:38.924Z
# 2    application/octet-stream       49468764  2023-10-08T01:01:29.601Z
# 3    application/octet-stream              0  2022-05-20T21:10:01.096Z
# 4    application/octet-stream              0  2022-05-20T23:16:00.981Z
# ..                        ...            ...                       ...
# 484  application/octet-stream              0  2022-05-21T07:46:13.000Z
# 485  application/octet-stream              0  2022-05-21T08:23:44.000Z
# 486  application/octet-stream              0  2022-05-21T08:03:10.000Z
# 487  application/octet-stream              0  2022-06-13T17:23:53.000Z
# 488  application/octet-stream              0  2022-05-20T23:37:26.000Z
#
#               PublicationDate          ModificationDate  Online EvictionDate  \
# 0    2023-05-15T22:18:17.975Z  2023-10-23T19:31:23.174Z    True
# 1    2023-10-18T16:41:04.686Z  2023-10-26T08:05:42.004Z    True
# 2    2023-10-24T10:33:20.056Z  2023-10-24T10:33:21.333Z    True
# 3    2022-05-20T22:15:04.642Z  2022-05-20T22:15:04.642Z    True
# 4    2022-05-21T00:18:30.620Z  2022-05-21T00:18:30.620Z    True
# ..                        ...                       ...     ...          ...
# 484  2022-05-21T09:57:42.455Z  2022-05-21T09:57:42.455Z    True
# 485  2022-05-21T09:59:14.519Z  2022-05-21T09:59:14.519Z    True
# 486  2022-05-21T10:00:58.434Z  2022-05-21T10:00:58.434Z    True
# 487  2022-06-13T18:28:42.098Z  2022-06-13T18:28:42.098Z    True
# 488  2022-05-20T23:53:45.939Z  2022-05-20T23:53:45.939Z    True
#
#                                                 S3Path  \
# 0    /eodata/Sentinel-5P/TROPOMI/L1B/2022/05/20/S5P...
# 1    /eodata/Sentinel-3/SRAL/SR_2_LAN_HY/2022/05/20...
# 2    /eodata/Sentinel-3/SRAL/SR_2_LAN_HY/2022/05/20...
# 3    /eodata/Sentinel-3/SRAL/SR_2_WAT/2022/05/20/S3...
# 4    /eodata/Sentinel-3/SLSTR/SL_2_WST/2022/05/20/S...
# ..                                                 ...
# 484  /eodata/Sentinel-6/P4/P4_1B_LR_____/2022/05/20...
# 485  /eodata/Sentinel-6/P4/P4_2__LR_____/2022/05/20...
# 486  /eodata/Sentinel-6/P4/P4_1B_LR_____/2022/05/20...
# 487  /eodata/Sentinel-6/AMR-C/MW_2__AMR____/2022/05...
# 488  /eodata/SMOS/L1CS/MIR_BWSF1C/2022/05/20/SM_OPE...
#
#                                               Checksum  \
# 0    [{'Value': '916176ed523714f544466a05f3b3d642',...
# 1    [{'Value': '26fdaa822cbb54f8832ebe9cca913553',...
# 2    [{'Value': '1f62866a87f210420715bb2b6c2c54d7',...
# 3                                                   []
# 4                                                   []
# ..                                                 ...
# 484                                                 []
# 485                                                 []
# 486                                                 []
# 487                                                 []
# 488                                                 []
#
#                                            ContentDate  \
# 0    {'Start': '2022-05-20T11:23:20.000Z', 'End': '...
# 1    {'Start': '2022-05-20T19:40:00.143Z', 'End': '...
# 2    {'Start': '2022-05-20T09:02:54.521Z', 'End': '...
# 3    {'Start': '2022-05-20T19:53:49.799Z', 'End': '...
# 4    {'Start': '2022-05-20T20:36:19.007Z', 'End': '...
# ..                                                 ...
# 484  {'Start': '2022-05-20T07:32:14.511Z', 'End': '...
# 485  {'Start': '2022-05-20T07:32:14.511Z', 'End': '...
# 486  {'Start': '2022-05-20T15:58:10.509Z', 'End': '...
# 487  {'Start': '2022-05-20T15:58:10.263Z', 'End': '...
# 488  {'Start': '2022-05-20T15:57:02.280Z', 'End': '...
#
#                                              Footprint  \
# 0    geography'SRID=4326;POLYGON ((-133.51479 47.45...
# 1    geography'SRID=4326;POLYGON ((37.8253 -17.6789...
# 2    geography'SRID=4326;POLYGON ((97.3771 81.361, ...
# 3    geography'SRID=4326;POLYGON ((26.3494 31.2806,...
# 4    geography'SRID=4326;POLYGON ((1.90709 51.3202,...
# ..                                                 ...
# 484  geography'SRID=4326;POLYGON ((-93.566095 -65.6...
# 485  geography'SRID=4326;POLYGON ((-93.566095 -65.6...
# 486  geography'SRID=4326;POLYGON ((-41.006483 66.64...
# 487  geography'SRID=4326;POLYGON ((84.6104 -59.3724...
# 488  geography'SRID=4326;MULTIPOLYGON (((-180 82.66...
#
#                                           GeoFootprint
# 0    {'type': 'Polygon', 'coordinates': [[[-133.514...
# 1    {'type': 'Polygon', 'coordinates': [[[37.8253,...
# 2    {'type': 'Polygon', 'coordinates': [[[97.3771,...
# 3    {'type': 'Polygon', 'coordinates': [[[26.3494,...
# 4    {'type': 'Polygon', 'coordinates': [[[1.90709,...
# ..                                                 ...
# 484  {'type': 'Polygon', 'coordinates': [[[-93.5660...
# 485  {'type': 'Polygon', 'coordinates': [[[-93.5660...
# 486  {'type': 'Polygon', 'coordinates': [[[-41.0064...
# 487  {'type': 'Polygon', 'coordinates': [[[84.6104,...
# 488  {'type': 'MultiPolygon', 'coordinates': [[[[-1...
#
# [489 rows x 15 columns]

# %%
list(df1['Name']) == list(df2['Name'])
all(item in list(df1['Name']) for item in list(df2['Name']))
# Out:
# True

# %%
list1 = [1, 3, 2]
list2 = [1, 2, 3]
all(item in list2 for item in list1)
# Out:
# True

# %%
json = requests.get("https://catalogue.dataspace.copernicus.eu/odata/v1/Products?$filter=Attributes/OData.CSC.DoubleAttribute/any(att:att/Name eq 'cloudCover' and att/OData.CSC.DoubleAttribute/Value le 40.00) and ContentDate/Start gt 2022-01-01T00:00:00.000Z and ContentDate/Start lt 2022-01-01T01:00:00.000Z&$top=1000").json()
df = pd.DataFrame.from_dict(json['value'])
df
# Out:
#       @odata.mediaContentType                                    Id  \
# 0    application/octet-stream  188dac27-d041-5674-9938-9a2d232e90a9
# 1    application/octet-stream  8a49d7d3-3bfb-581e-9bdd-74f604af295c
# 2    application/octet-stream  124a4d26-6720-5d05-b0a6-25b03cc254d7
# 3    application/octet-stream  74bb8ef7-d552-59b6-abc1-45c01539dfc1
# 4    application/octet-stream  a8446813-6458-549e-a80e-0d6855c7df52
# ..                        ...                                   ...
# 324  application/octet-stream  d4ceaacf-a6ed-5030-a8eb-9fecd35b18aa
# 325  application/octet-stream  b61c05db-460c-5100-80e0-4fc7d1b9d725
# 326  application/octet-stream  9a5dc1bf-45c9-525a-b29d-ea387a2d2aab
# 327  application/octet-stream  86c555c9-a914-5a66-8ced-8258ecf2be78
# 328  application/octet-stream  c9b09b37-9661-55b1-bd2e-b47b1d263e94
#
#                                                   Name  \
# 0    S3B_SY_2_VGP____20220101T001118_20220101T00551...
# 1    S3B_SY_2_VGP____20220101T001118_20220101T00551...
# 2    S3B_SY_2_SYN____20220101T003047_20220101T00334...
# 3    S3B_SY_2_SYN____20220101T003047_20220101T00334...
# 4    S3B_SY_2_SYN____20220101T003347_20220101T00364...
# ..                                                 ...
# 324  S2A_MSIL1C_20220101T005821_N0301_R059_T49CDR_2...
# 325  S2A_MSIL1C_20220101T005821_N0301_R059_T48CWA_2...
# 326  S2A_MSIL2A_20220101T005821_N0301_R059_T48CVA_2...
# 327  S2A_MSIL1C_20220101T005821_N0301_R059_T49CDQ_2...
# 328  S2A_MSIL2A_20220101T005821_N0301_R059_T48CVC_2...
#
#                   ContentType  ContentLength                OriginDate  \
# 0    application/octet-stream              0  2022-01-01T11:04:30.327Z
# 1    application/octet-stream              0  2022-01-02T21:43:30.523Z
# 2    application/octet-stream              0  2022-01-01T11:11:05.339Z
# 3    application/octet-stream              0  2022-01-02T21:50:31.361Z
# 4    application/octet-stream              0  2022-01-01T11:13:31.579Z
# ..                        ...            ...                       ...
# 324  application/octet-stream              0  2022-01-01T02:33:10.300Z
# 325  application/octet-stream              0  2022-01-01T02:33:06.855Z
# 326  application/octet-stream              0  2022-01-01T03:35:22.907Z
# 327  application/octet-stream              0  2022-01-01T02:29:00.642Z
# 328  application/octet-stream              0  2022-01-01T03:35:19.798Z
#
#               PublicationDate          ModificationDate  Online EvictionDate  \
# 0    2022-01-01T11:10:00.875Z  2022-01-01T11:10:00.875Z    True
# 1    2022-01-02T21:46:41.718Z  2022-01-02T21:46:41.718Z    True
# 2    2022-01-01T11:15:07.507Z  2022-01-01T11:15:07.507Z    True
# 3    2022-01-02T21:56:03.932Z  2022-01-02T21:56:03.932Z    True
# 4    2022-01-01T11:19:26.701Z  2022-01-01T11:19:26.701Z    True
# ..                        ...                       ...     ...          ...
# 324  2022-01-01T02:33:13.592Z  2022-01-01T02:33:13.592Z    True
# 325  2022-01-01T02:33:10.336Z  2022-01-01T02:33:10.336Z    True
# 326  2022-06-06T16:18:42.224Z  2022-06-06T16:18:42.224Z    True
# 327  2022-01-01T02:33:01.068Z  2022-01-01T02:33:01.068Z    True
# 328  2022-06-06T16:37:24.638Z  2022-06-06T16:37:24.638Z    True
#
#                                                 S3Path Checksum  \
# 0    /eodata/Sentinel-3/SYNERGY/SY_2_VGP___/2022/01...       []
# 1    /eodata/Sentinel-3/SYNERGY/SY_2_VGP___/2022/01...       []
# 2    /eodata/Sentinel-3/SYNERGY/SY_2_SYN___/2022/01...       []
# 3    /eodata/Sentinel-3/SYNERGY/SY_2_SYN___/2022/01...       []
# 4    /eodata/Sentinel-3/SYNERGY/SY_2_SYN___/2022/01...       []
# ..                                                 ...      ...
# 324  /eodata/Sentinel-2/MSI/L1C/2022/01/01/S2A_MSIL...       []
# 325  /eodata/Sentinel-2/MSI/L1C/2022/01/01/S2A_MSIL...       []
# 326  /eodata/Sentinel-2/MSI/L2A/2022/01/01/S2A_MSIL...       []
# 327  /eodata/Sentinel-2/MSI/L1C/2022/01/01/S2A_MSIL...       []
# 328  /eodata/Sentinel-2/MSI/L2A/2022/01/01/S2A_MSIL...       []
#
#                                            ContentDate  \
# 0    {'Start': '2022-01-01T00:11:17.705Z', 'End': '...
# 1    {'Start': '2022-01-01T00:11:17.705Z', 'End': '...
# 2    {'Start': '2022-01-01T00:30:46.631Z', 'End': '...
# 3    {'Start': '2022-01-01T00:30:46.631Z', 'End': '...
# 4    {'Start': '2022-01-01T00:33:46.631Z', 'End': '...
# ..                                                 ...
# 324  {'Start': '2022-01-01T00:58:21.024Z', 'End': '...
# 325  {'Start': '2022-01-01T00:58:21.024Z', 'End': '...
# 326  {'Start': '2022-01-01T00:58:21.024Z', 'End': '...
# 327  {'Start': '2022-01-01T00:58:21.024Z', 'End': '...
# 328  {'Start': '2022-01-01T00:58:21.024Z', 'End': '...
#
#                                              Footprint  \
# 0    geography'SRID=4326;POLYGON ((144.99 57.6144, ...
# 1    geography'SRID=4326;POLYGON ((144.99 57.6144, ...
# 2    geography'SRID=4326;POLYGON ((128.722 -21.0345...
# 3    geography'SRID=4326;POLYGON ((128.722 -21.0345...
# 4    geography'SRID=4326;POLYGON ((125.061 -31.3554...
# ..                                                 ...
# 324  geography'SRID=4326;POLYGON ((109.0765016672 -...
# 325  geography'SRID=4326;POLYGON ((109.0765016672 -...
# 326  geography'SRID=4326;POLYGON ((105.35565624647 ...
# 327  geography'SRID=4326;POLYGON ((111.12292983372 ...
# 328  geography'SRID=4326;POLYGON ((102.65175365242 ...
#
#                                           GeoFootprint
# 0    {'type': 'Polygon', 'coordinates': [[[144.99, ...
# 1    {'type': 'Polygon', 'coordinates': [[[144.99, ...
# 2    {'type': 'Polygon', 'coordinates': [[[128.722,...
# 3    {'type': 'Polygon', 'coordinates': [[[128.722,...
# 4    {'type': 'Polygon', 'coordinates': [[[125.061,...
# ..                                                 ...
# 324  {'type': 'Polygon', 'coordinates': [[[109.0765...
# 325  {'type': 'Polygon', 'coordinates': [[[109.0765...
# 326  {'type': 'Polygon', 'coordinates': [[[105.3556...
# 327  {'type': 'Polygon', 'coordinates': [[[111.1229...
# 328  {'type': 'Polygon', 'coordinates': [[[102.6517...
#
# [329 rows x 15 columns]

# %%
data_gdf = qr.fetch_data(geometry='POLYGON((12.655118166047592 47.44667197521409,21.39065656328509 48.347694733853245,28.334291357162826 41.877123516783655,17.47086198383573 40.35854475076158,12.655118166047592 47.44667197521409))', start_datetime='2022-05-20 00:00:00', end_datetime='2022-05-21 00:00:00', top=1000)
data_gdf

# %%
data_cloud = qr.fetch_data(max_cloud_percent=40,start_datetime='2022-01-01 00:00:00', end_datetime='2022-01-01 01:00:00')
# Out:
# DEBUG:root:normalize_gdf processing time:0.008809566497802734s
# DEBUG:root:#########
# DEBUG:root:creat_urls processing time:0.0009126663208007812s
# 100%|█████████████████████████████████████████████| 1/1 [00:02<00:00,  2.99s/it]
# DEBUG:root:remove_duplicates time: 0.0009319782257080078s

# %%
data_cloud
# Out:
#       @odata.mediaContentType                                    Id  \
# 0    application/octet-stream  188dac27-d041-5674-9938-9a2d232e90a9
# 1    application/octet-stream  8a49d7d3-3bfb-581e-9bdd-74f604af295c
# 2    application/octet-stream  124a4d26-6720-5d05-b0a6-25b03cc254d7
# 3    application/octet-stream  74bb8ef7-d552-59b6-abc1-45c01539dfc1
# 4    application/octet-stream  a8446813-6458-549e-a80e-0d6855c7df52
# ..                        ...                                   ...
# 324  application/octet-stream  d4ceaacf-a6ed-5030-a8eb-9fecd35b18aa
# 325  application/octet-stream  b61c05db-460c-5100-80e0-4fc7d1b9d725
# 326  application/octet-stream  9a5dc1bf-45c9-525a-b29d-ea387a2d2aab
# 327  application/octet-stream  86c555c9-a914-5a66-8ced-8258ecf2be78
# 328  application/octet-stream  c9b09b37-9661-55b1-bd2e-b47b1d263e94
#
#                                                   Name  \
# 0    S3B_SY_2_VGP____20220101T001118_20220101T00551...
# 1    S3B_SY_2_VGP____20220101T001118_20220101T00551...
# 2    S3B_SY_2_SYN____20220101T003047_20220101T00334...
# 3    S3B_SY_2_SYN____20220101T003047_20220101T00334...
# 4    S3B_SY_2_SYN____20220101T003347_20220101T00364...
# ..                                                 ...
# 324  S2A_MSIL1C_20220101T005821_N0301_R059_T49CDR_2...
# 325  S2A_MSIL1C_20220101T005821_N0301_R059_T48CWA_2...
# 326  S2A_MSIL2A_20220101T005821_N0301_R059_T48CVA_2...
# 327  S2A_MSIL1C_20220101T005821_N0301_R059_T49CDQ_2...
# 328  S2A_MSIL2A_20220101T005821_N0301_R059_T48CVC_2...
#
#                   ContentType  ContentLength                OriginDate  \
# 0    application/octet-stream              0  2022-01-01T11:04:30.327Z
# 1    application/octet-stream              0  2022-01-02T21:43:30.523Z
# 2    application/octet-stream              0  2022-01-01T11:11:05.339Z
# 3    application/octet-stream              0  2022-01-02T21:50:31.361Z
# 4    application/octet-stream              0  2022-01-01T11:13:31.579Z
# ..                        ...            ...                       ...
# 324  application/octet-stream              0  2022-01-01T02:33:10.300Z
# 325  application/octet-stream              0  2022-01-01T02:33:06.855Z
# 326  application/octet-stream              0  2022-01-01T03:35:22.907Z
# 327  application/octet-stream              0  2022-01-01T02:29:00.642Z
# 328  application/octet-stream              0  2022-01-01T03:35:19.798Z
#
#               PublicationDate          ModificationDate  Online EvictionDate  \
# 0    2022-01-01T11:10:00.875Z  2022-01-01T11:10:00.875Z    True
# 1    2022-01-02T21:46:41.718Z  2022-01-02T21:46:41.718Z    True
# 2    2022-01-01T11:15:07.507Z  2022-01-01T11:15:07.507Z    True
# 3    2022-01-02T21:56:03.932Z  2022-01-02T21:56:03.932Z    True
# 4    2022-01-01T11:19:26.701Z  2022-01-01T11:19:26.701Z    True
# ..                        ...                       ...     ...          ...
# 324  2022-01-01T02:33:13.592Z  2022-01-01T02:33:13.592Z    True
# 325  2022-01-01T02:33:10.336Z  2022-01-01T02:33:10.336Z    True
# 326  2022-06-06T16:18:42.224Z  2022-06-06T16:18:42.224Z    True
# 327  2022-01-01T02:33:01.068Z  2022-01-01T02:33:01.068Z    True
# 328  2022-06-06T16:37:24.638Z  2022-06-06T16:37:24.638Z    True
#
#                                                 S3Path Checksum  \
# 0    /eodata/Sentinel-3/SYNERGY/SY_2_VGP___/2022/01...       []
# 1    /eodata/Sentinel-3/SYNERGY/SY_2_VGP___/2022/01...       []
# 2    /eodata/Sentinel-3/SYNERGY/SY_2_SYN___/2022/01...       []
# 3    /eodata/Sentinel-3/SYNERGY/SY_2_SYN___/2022/01...       []
# 4    /eodata/Sentinel-3/SYNERGY/SY_2_SYN___/2022/01...       []
# ..                                                 ...      ...
# 324  /eodata/Sentinel-2/MSI/L1C/2022/01/01/S2A_MSIL...       []
# 325  /eodata/Sentinel-2/MSI/L1C/2022/01/01/S2A_MSIL...       []
# 326  /eodata/Sentinel-2/MSI/L2A/2022/01/01/S2A_MSIL...       []
# 327  /eodata/Sentinel-2/MSI/L1C/2022/01/01/S2A_MSIL...       []
# 328  /eodata/Sentinel-2/MSI/L2A/2022/01/01/S2A_MSIL...       []
#
#                                            ContentDate  \
# 0    {'Start': '2022-01-01T00:11:17.705Z', 'End': '...
# 1    {'Start': '2022-01-01T00:11:17.705Z', 'End': '...
# 2    {'Start': '2022-01-01T00:30:46.631Z', 'End': '...
# 3    {'Start': '2022-01-01T00:30:46.631Z', 'End': '...
# 4    {'Start': '2022-01-01T00:33:46.631Z', 'End': '...
# ..                                                 ...
# 324  {'Start': '2022-01-01T00:58:21.024Z', 'End': '...
# 325  {'Start': '2022-01-01T00:58:21.024Z', 'End': '...
# 326  {'Start': '2022-01-01T00:58:21.024Z', 'End': '...
# 327  {'Start': '2022-01-01T00:58:21.024Z', 'End': '...
# 328  {'Start': '2022-01-01T00:58:21.024Z', 'End': '...
#
#                                              Footprint  \
# 0    geography'SRID=4326;POLYGON ((144.99 57.6144, ...
# 1    geography'SRID=4326;POLYGON ((144.99 57.6144, ...
# 2    geography'SRID=4326;POLYGON ((128.722 -21.0345...
# 3    geography'SRID=4326;POLYGON ((128.722 -21.0345...
# 4    geography'SRID=4326;POLYGON ((125.061 -31.3554...
# ..                                                 ...
# 324  geography'SRID=4326;POLYGON ((109.0765016672 -...
# 325  geography'SRID=4326;POLYGON ((109.0765016672 -...
# 326  geography'SRID=4326;POLYGON ((105.35565624647 ...
# 327  geography'SRID=4326;POLYGON ((111.12292983372 ...
# 328  geography'SRID=4326;POLYGON ((102.65175365242 ...
#
#                                           GeoFootprint  \
# 0    {'type': 'Polygon', 'coordinates': [[[144.99, ...
# 1    {'type': 'Polygon', 'coordinates': [[[144.99, ...
# 2    {'type': 'Polygon', 'coordinates': [[[128.722,...
# 3    {'type': 'Polygon', 'coordinates': [[[128.722,...
# 4    {'type': 'Polygon', 'coordinates': [[[125.061,...
# ..                                                 ...
# 324  {'type': 'Polygon', 'coordinates': [[[109.0765...
# 325  {'type': 'Polygon', 'coordinates': [[[109.0765...
# 326  {'type': 'Polygon', 'coordinates': [[[105.3556...
# 327  {'type': 'Polygon', 'coordinates': [[[111.1229...
# 328  {'type': 'Polygon', 'coordinates': [[[102.6517...
#
#                                             Attributes  input_index
# 0    [{'@odata.type': '#OData.CSC.StringAttribute',...            0
# 1    [{'@odata.type': '#OData.CSC.StringAttribute',...            0
# 2    [{'@odata.type': '#OData.CSC.StringAttribute',...            0
# 3    [{'@odata.type': '#OData.CSC.StringAttribute',...            0
# 4    [{'@odata.type': '#OData.CSC.StringAttribute',...            0
# ..                                                 ...          ...
# 324  [{'@odata.type': '#OData.CSC.StringAttribute',...            0
# 325  [{'@odata.type': '#OData.CSC.StringAttribute',...            0
# 326  [{'@odata.type': '#OData.CSC.StringAttribute',...            0
# 327  [{'@odata.type': '#OData.CSC.StringAttribute',...            0
# 328  [{'@odata.type': '#OData.CSC.StringAttribute',...            0
#
# [329 rows x 17 columns]

# %%
"""Tests for fetch_data function."""
import pytest
import requests
import pandas as pd
import cdsodatacli.query as qr


# Test for Query Collection of Products
name_json = requests.get("https://catalogue.dataspace.copernicus.eu/odata/v1/Products?$filter=Collection/Name eq 'SENTINEL-2' and ContentDate/Start gt 2022-05-03T00:00:00.000Z and ContentDate/Start lt 2022-05-03T00:11:00.000Z&$top=1000").json()
name_df = pd.DataFrame.from_dict(name_json['value'])
query_name_dfd = qr.fetch_data(collection='SENTINEL-2', start_datetime='2022-05-03 00:00:00', end_datetime='2022-05-03 00:11:00', top=1000)

# Test Query by Geographic Criteria
geographic_json = requests.get("https://catalogue.dataspace.copernicus.eu/odata/v1/Products?$filter=OData.CSC.Intersects(area=geography'SRID=4326;POLYGON((12.655118166047592 47.44667197521409,21.39065656328509 48.347694733853245,28.334291357162826 41.877123516783655,17.47086198383573 40.35854475076158,12.655118166047592 47.44667197521409))') and ContentDate/Start gt 2022-05-20T00:00:00.000Z and ContentDate/Start lt 2022-05-21T00:00:00.000Z&$top=1000").json()
geographic_df = pd.DataFrame.from_dict(geographic_json['value'])
query_geographic_name = qr.fetch_data(geometry='POLYGON((12.655118166047592 47.44667197521409,21.39065656328509 48.347694733853245,28.334291357162826 41.877123516783655,17.47086198383573 40.35854475076158,12.655118166047592 47.44667197521409))', start_datetime='2022-05-20 00:00:00', end_datetime='2022-05-21 00:00:00', top=1000)

# Test Query by attributes
cloudCover_json = requests.get("https://catalogue.dataspace.copernicus.eu/odata/v1/Products?$filter=Attributes/OData.CSC.DoubleAttribute/any(att:att/Name eq 'cloudCover' and att/OData.CSC.DoubleAttribute/Value le 40.00) and ContentDate/Start gt 2022-01-01T00:00:00.000Z and ContentDate/Start lt 2022-01-01T01:00:00.000Z&$top=1000").json()
cloudCover_df = pd.DataFrame.from_dict(cloudCover_json['value'])
query_cloudCover_df = qr.fetch_data(max_cloud_percent=40, start_datetime='2022-01-01 00:00:00', end_datetime='2022-01-01 01:00:00')


def test_queryname(query_name_dfd=query_name_dfd, name_df=name_df):
    """Example test with parametrization."""
    assert all(item in list(query_name_dfd['Name']) for item in list(name_df['Name']))


def test_querygeographic(query_geographic_name=query_geographic_name, geographic_df=geographic_df):
    """Example test with parametrization."""
    assert all(item in list(query_geographic_name['Name']) for item in list(geographic_df['Name']))


def test_querycloudcover(query_cloudCover_df=query_cloudCover_df, cloudCover_df=cloudCover_df):
    """Example test with parametrization."""
    assert all(item in list(query_cloudCover_df['Name']) for item in list(cloudCover_df['Name']))
